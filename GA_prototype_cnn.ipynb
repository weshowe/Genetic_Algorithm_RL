# %%
"""
Dependencies: gym, ale-py

pip install gym[atari,accept-rom-license]

"""

import gym
import random
import numpy as np

from copy import copy, deepcopy

from functools import cmp_to_key

import torch
from torch import nn
from torchvision import transforms

import pickle
import time

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform_obs = transforms.Compose([
    transforms.ToTensor(),
    transforms.Grayscale(),
    transforms.Resize(size=(84,84)),
    transforms.Normalize([0.5], [0.5]),

])

def obs_to_tensor(obs):
   return torch.squeeze(transform_obs(np.array(obs)).to(device), 0)

# Initialize weights to something random.
def init_weights_cnn(m):
    if (isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d)):
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

# CNN used for determining actions.
class Agent_CNN(nn.Module):
  def __init__(self):
    super().__init__() 
    self.model = nn.Sequential(
            # Block 1
                nn.Conv2d(in_channels=4, out_channels=32, kernel_size=(8,8), stride=(4), bias=True),
                nn.ReLU(),
                nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(4,4), stride=(2), bias=True),
                nn.ReLU(),
                nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3,3), stride=(1), bias=True),
                nn.ReLU(),
                nn.Flatten(), 
                nn.Linear(in_features=3136, out_features=512, bias=True),
                nn.ReLU(),
                nn.Linear(in_features=512, out_features=7, bias=True),
                nn.ReLU(),
                nn.Softmax(),
            )
    
    self.model.apply(init_weights_cnn)
    
  def forward(self, x):
    with torch.no_grad():
      arr = self.model(x)
      arr = arr.cpu().detach().numpy()
      action = np.argmax(arr)
      return action

  def getWeights(self):
    weight_dict = {}
    weight_dict["l1"] = self.model[0].weight.cpu().detach().numpy()
    weight_dict["l2"] = self.model[2].weight.cpu().detach().numpy()
    weight_dict["l3"] = self.model[4].weight.cpu().detach().numpy()
    weight_dict["l4"] = self.model[7].weight.cpu().detach().numpy()
    weight_dict["l5"] = self.model[9].weight.cpu().detach().numpy()

    return weight_dict
    
  def setWeights(self, weight_dict):

    self.model[0].weight = nn.Parameter(torch.from_numpy(weight_dict["l1"]).float().to(device), requires_grad = False)
    self.model[2].weight = nn.Parameter(torch.from_numpy(weight_dict["l2"]).float().to(device), requires_grad = False)
    self.model[4].weight = nn.Parameter(torch.from_numpy(weight_dict["l3"]).float().to(device), requires_grad = False)
    self.model[7].weight = nn.Parameter(torch.from_numpy(weight_dict["l4"]).float().to(device), requires_grad = False)
    self.model[9].weight = nn.Parameter(torch.from_numpy(weight_dict["l5"]).float().to(device), requires_grad = False)

# %%
# Syntactic sugar for restacking frames
def restack(t2, t3, t4, obs):
    return t2, t3, t4, obs

"""
Action space is of size 7:

0 NOOP
1 FIRE
2 UP
3 RIGHT
4 LEFT
5 RIGHTFIRE
6 LEFTFIRE
"""

"""
A class for each chromosome.
"""
class Chromosome:

    """
    This is used to initialize a chromosome

    args is used since Python doesn't support multiple constructors. (self, env) initializes a chromosome with a random
    action sequence and is used during population initialization.

    (self, actions, env) is used during crossover to generate new chromosomes given a crossed action buffer.
    """
    def __init__(self, *args):

        if len(args) > 1:
            self.nn = Agent_CNN()
            self.nn.to(device)
            self.nn.eval()
            self.nn.setWeights(args[0])
            self.env = args[1]
            self.reward_sum = 0
            self.time_alive = 0
            self.updated = False

            return

        # Stores actions taken, rewards obtained, total reward for the run, and the number of frames that the agent has been alive for.

        self.nn = Agent_CNN()
        self.nn.to(device)
        self.nn.eval()
        self.updated = False

        self.reward_sum = 0
        self.time_alive = 0

        # Store the provided env as a class variable.
        self.env = args[0]

        obs = self.env.reset()
        frame1 = obs_to_tensor(obs)
        frame2 = deepcopy(frame1)
        frame3 = deepcopy(frame1)
        frame4 = deepcopy(frame1)
        done = False

        while(done == False):

            stacked_obs = torch.unsqueeze(torch.stack([frame1, frame2, frame3, frame4]), 0)

            action = self.nn(stacked_obs)

            obs, reward, done, info = self.env.step(action)
            frame1, frame2, frame3, frame4 = restack(frame2, frame3, frame4, obs_to_tensor(obs))

            self.time_alive = self.time_alive + 1
            self.reward_sum = self.reward_sum + reward

    """
    This reruns the environment and performs a new run with the updated NN to generate new stats.

    Runs a specified number of times and averages all results.

    If we've already updated, don't update again. Done so elites aren't recalculated when they don't need to be.
    """
    def update(self, num):

        if self.updated:
            return

        # Stores updated actions and rewards taken.
        self.nn.eval()

        times = []
        scores = []

        for i in range(0, num):
            curReward = 0
            curTime = 0

            obs = self.env.reset()
            frame1 = obs_to_tensor(obs)
            frame2 = deepcopy(frame1)
            frame3 = deepcopy(frame1)
            frame4 = deepcopy(frame1)

            done = False

            while(done == False):

                stacked_obs = torch.unsqueeze(torch.stack([frame1, frame2, frame3, frame4]), 0)

                action = self.nn(stacked_obs)

                obs, reward, done, info = self.env.step(action)
                frame1, frame2, frame3, frame4 = restack(frame2, frame3, frame4, obs_to_tensor(obs))

                curTime = curTime + 1
                curReward = curReward + reward

            times.append(curTime)
            scores.append(curReward)

        self.reward_sum = np.mean(np.array(scores))
        self.time_alive = np.mean(np.array(times))

        self.updated = True

    """
    This mutates a chromosome's genes (NN weights) based on a supplied probability. If the mutation occurs, the action is replaced with a random one.
    """
    def mutate(self, mutation_rate, mutation_factor=0.01):
        weight_dict = self.nn.getWeights()
        for key, val in weight_dict.items():
            std = np.std(val)
            for i in range(0, len(val)):
                for j in range(0, len(val[i])):
                    if random.random() <= mutation_rate:
                        curWeight = val[i][j]
                        mutation_amount = np.random.normal(0, std)
                        val[i][j] = curWeight + mutation_amount

            weight_dict[key] = val

        self.nn.setWeights(weight_dict)

# %%
"""
GA and helper methods
"""

#Comparator for a Chromosome list
def chromosome_comparator(a, b):
    if a.reward_sum > b.reward_sum:
        return 1
    elif a.reward_sum == b.reward_sum:
        if a.time_alive < b.time_alive:
            return 1
        else:
            return -1
    else:
        return -1

# Feed this to sorting function
compare_key = cmp_to_key(chromosome_comparator)

# Generates initial population
def create_initial_population(number, env):
    population = []

    for i in range(0, number):
        population.append(Chromosome(env))

    return population

def list_population(population):
    outString = ""

    for i, chrom in enumerate(population):
        outString = outString + f"Chromosome {i+1}: Score - {chrom.reward_sum}   Time: {chrom.time_alive} * "

    print(outString)


"""
Applies a fitness function and then ranks the population in descending order of best to worst.

In this case, the primary marker of fitness is the high score. Assuming a tie, then secondary criterion is how long each agent has been alive.

Also returns the best chromosome found.
"""
def selection(population):

    # The first stage is the fitness function.
    optimal_index = 0
    longest_alive = 1000000
    max_score = 0
    n = len(population)
    scores = []

    for i, chrom in enumerate(population):

        chrom.update(5)

        if chrom.reward_sum > max_score:
            best = True
        elif (chrom.reward_sum == max_score) and longest_alive < chrom.time_alive:
            best = True
        else:
            best = False

        if best:
            longest_alive = chrom.time_alive
            max_score = chrom.reward_sum
            optimal_index = i

    selected_population = []

    # Select best chromosome.
    best_chromosome = deepcopy(population[optimal_index])
    population.sort(key=compare_key, reverse=True)

    for l in range(0, int(len(population) / 10)):  
        selected_population.append(population.pop(l))

    scores = []
    for l in range(0, len(population)):
        scores.append(population[l].reward_sum)

    scores = [1 if x <=0 else x for x in scores]

    scores = np.array(scores)

    # Select chromosomes probabilistically.
    for k in range(0, int(len(population)/2) - int(len(selected_population) / 2)):
        probs = scores / np.sum(scores)

        ind = np.random.choice(np.arange(0, len(population)), size=None, replace=True, p=probs)
        selected_population.append(population.pop(ind))

        scores = np.delete(scores, ind)
    
    selected_population.sort(key=compare_key, reverse=True)
    list_population(selected_population)

    return selected_population, best_chromosome

"""
Performs crossover on a population and returns the new population.

Crossover is done by combining the weights of the parental nns.
"""
def crossover(population):

    n = len(population) * 2
    scores = []
    for i in range(0, len(population)):
        scores.append(population[i].reward_sum)
    
    scores = [1 if x <=0 else x for x in scores]
    scores = np.array(scores)

    crossed_population = []

    i = 0

    scores_new = deepcopy(scores)

    while len(crossed_population) < n:

        if i < int(n / 10):
            crossed_population.append(population[i])
            i = i + 1
            continue

        if np.count_nonzero(scores_new) < 2:
            scores_new = deepcopy(scores)


        probs = scores_new / np.sum(scores_new)

        father_index = np.random.choice(np.arange(0, len(population)), size=None, replace=True, p=probs)
        father = population[father_index]
        scores_new[father_index] = 0

        probs = scores_new / np.sum(scores_new)

        mother_index = np.random.choice(np.arange(0, len(population)), size=None, replace=True, p=probs)
        mother = population[mother_index]
        scores_new[mother_index] = 0

        motherWeights = mother.nn.getWeights()
        fatherWeights = father.nn.getWeights()

        newWeights = deepcopy(fatherWeights)
        newWeights2 = deepcopy(fatherWeights)
            
        for key, val in newWeights.items():
            for k in range(0, len(val)):
                
                crossover_point = random.randint(0, len(val[k]))

                for l in range(0, len(val[k])):
                    if l >= crossover_point:
                        
                        newWeights[key][k][l] = motherWeights[key][k][l]
                        newWeights2[key][k][l] = fatherWeights[key][k][l]

                        newWeights[key][k][l] = fatherWeights[key][k][l]
                        newWeights2[key][k][l] = motherWeights[key][k][l]

        crossed_population.append(Chromosome(newWeights, father.env))
        crossed_population.append(Chromosome(newWeights2, father.env))

        i = i+1


    return crossed_population[0:n]

"""
Mutate the population. Rate represents chance of mutation.
"""
def mutate_population(population, rate=0.001):
    for i, chrom in enumerate(population):

        # Don't mutate the best chromosomes retained from previous population
        if i < int(len(population) / 10):
            continue 
        
        else:
            chrom.mutate(rate)

"""
Rerun the environment for all chromosomes and produce updated runs.
"""
def update_population(population):
    for i, chrom in enumerate(population):   
         chrom.update()

# %%
"""
GA loop
"""

env = gym.make('ALE/Assault-v5', full_action_space=False)

n_iter = 100
population_size = 200
mutation_rate = 0.002

best_alive = 10000000
best_score = 0
best_chromo = None

population = create_initial_population(population_size, env)

start_time = time.time()

for i in range(0, n_iter):

    # Run the fitness function and determine if the best chromosome is better than the best one we've stored for all runs.
    selected_population, best_chromo_candidate = selection(population)
    longest_alive = best_chromo_candidate.time_alive
    max_score = best_chromo_candidate.reward_sum

    if best_chromo_candidate.reward_sum > best_score:
            best = True
    elif (best_chromo_candidate.reward_sum == best_score) and best_chromo_candidate.time_alive < best_alive:
            best = True
    else:
        if i == 0:
                best = True
        else:
                best = False

    if best:
           best_chromo = deepcopy(best_chromo_candidate)
           best_alive = best_chromo_candidate.time_alive
           best_score = best_chromo_candidate.reward_sum

           file = open(f'best_chromo_{start_time}.pickle', 'wb')

           # dump information to that file
           pickle.dump(best_chromo, file)

           # close the file
           file.close()
           

    # Print stats.
    print(f"Best Chromosome for Run {i + 1} -> Time Alive: {longest_alive}    High Score: {max_score}")

    # Cross, Mutate, and prepare the new population for the next run.
    crossed_population = crossover(selected_population)
    mutate_population(crossed_population, mutation_rate)

    population = crossed_population

print(f"Best Chromosome -> Time Alive: {best_alive}    High Score: {best_score}")
# Out:
# c:\Users\icarus\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\container.py:204: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Chromosome 1: Score - 483.0   Time: 673.6 * Chromosome 2: Score - 474.6   Time: 624.6 * Chromosome 3: Score - 453.6   Time: 619.0 * Chromosome 4: Score - 453.6   Time: 639.4 * Chromosome 5: Score - 449.4   Time: 858.2 * Chromosome 6: Score - 445.2   Time: 641.4 * Chromosome 7: Score - 445.2   Time: 1276.8 * Chromosome 8: Score - 428.4   Time: 592.4 * Chromosome 9: Score - 428.4   Time: 713.8 * Chromosome 10: Score - 424.2   Time: 635.0 * Chromosome 11: Score - 424.2   Time: 648.6 * Chromosome 12: Score - 420.0   Time: 593.4 * Chromosome 13: Score - 420.0   Time: 607.8 * Chromosome 14: Score - 399.0   Time: 570.4 * Chromosome 15: Score - 399.0   Time: 583.8 * Chromosome 16: Score - 399.0   Time: 2385.6 * Chromosome 17: Score - 378.0   Time: 586.8 * Chromosome 18: Score - 373.8   Time: 573.6 * Chromosome 19: Score - 361.2   Time: 582.2 * Chromosome 20: Score - 352.8   Time: 550.4 * Chromosome 21: Score - 340.2   Time: 481.2 * Chromosome 22: Score - 340.2   Time: 2105.0 * Chromosome 23: Score - 331.8   Time: 502.6 * Chromosome 24: Score - 331.8   Time: 631.6 * Chromosome 25: Score - 323.4   Time: 531.4 * Chromosome 26: Score - 310.8   Time: 510.2 * Chromosome 27: Score - 306.6   Time: 490.0 * Chromosome 28: Score - 302.4   Time: 488.2 * Chromosome 29: Score - 218.4   Time: 5403.6 * Chromosome 30: Score - 180.6   Time: 2478.6 * Chromosome 31: Score - 134.4   Time: 5019.6 * Chromosome 32: Score - 88.2   Time: 2165.2 * Chromosome 33: Score - 54.6   Time: 2850.0 * Chromosome 34: Score - 29.4   Time: 373.4 * Chromosome 35: Score - 21.0   Time: 821.2 * Chromosome 36: Score - 21.0   Time: 5614.8 * Chromosome 37: Score - 12.6   Time: 335.8 * Chromosome 38: Score - 0.0   Time: 206.8 * Chromosome 39: Score - 0.0   Time: 206.8 * Chromosome 40: Score - 0.0   Time: 209.0 * Chromosome 41: Score - 0.0   Time: 250.6 * Chromosome 42: Score - 0.0   Time: 264.4 * Chromosome 43: Score - 0.0   Time: 266.8 * Chromosome 44: Score - 0.0   Time: 297.4 * Chromosome 45: Score - 0.0   Time: 309.4 * Chromosome 46: Score - 0.0   Time: 315.8 * Chromosome 47: Score - 0.0   Time: 328.4 * Chromosome 48: Score - 0.0   Time: 331.8 * Chromosome 49: Score - 0.0   Time: 341.4 * Chromosome 50: Score - 0.0   Time: 350.0 * Chromosome 51: Score - 0.0   Time: 357.4 * Chromosome 52: Score - 0.0   Time: 370.2 * Chromosome 53: Score - 0.0   Time: 373.4 * Chromosome 54: Score - 0.0   Time: 375.6 * Chromosome 55: Score - 0.0   Time: 377.0 * Chromosome 56: Score - 0.0   Time: 384.4 * Chromosome 57: Score - 0.0   Time: 384.4 * Chromosome 58: Score - 0.0   Time: 403.6 * Chromosome 59: Score - 0.0   Time: 423.8 * Chromosome 60: Score - 0.0   Time: 451.4 * Chromosome 61: Score - 0.0   Time: 462.8 * Chromosome 62: Score - 0.0   Time: 469.2 * Chromosome 63: Score - 0.0   Time: 498.0 * Chromosome 64: Score - 0.0   Time: 548.6 * Chromosome 65: Score - 0.0   Time: 565.2 * Chromosome 66: Score - 0.0   Time: 567.6 * Chromosome 67: Score - 0.0   Time: 841.8 * Chromosome 68: Score - 0.0   Time: 923.6 * Chromosome 69: Score - 0.0   Time: 1474.6 * Chromosome 70: Score - 0.0   Time: 1512.4 * Chromosome 71: Score - 0.0   Time: 1589.2 * Chromosome 72: Score - 0.0   Time: 1678.8 * Chromosome 73: Score - 0.0   Time: 1934.8 * Chromosome 74: Score - 0.0   Time: 1966.8 * Chromosome 75: Score - 0.0   Time: 2018.0 * Chromosome 76: Score - 0.0   Time: 2088.4 * Chromosome 77: Score - 0.0   Time: 2190.8 * Chromosome 78: Score - 0.0   Time: 2254.8 * Chromosome 79: Score - 0.0   Time: 2459.6 * Chromosome 80: Score - 0.0   Time: 2638.8 * Chromosome 81: Score - 0.0   Time: 2664.4 * Chromosome 82: Score - 0.0   Time: 2702.8 * Chromosome 83: Score - 0.0   Time: 2850.0 * Chromosome 84: Score - 0.0   Time: 2926.8 * Chromosome 85: Score - 0.0   Time: 3298.0 * Chromosome 86: Score - 0.0   Time: 3419.6 * Chromosome 87: Score - 0.0   Time: 3483.6 * Chromosome 88: Score - 0.0   Time: 3534.8 * Chromosome 89: Score - 0.0   Time: 3675.6 * Chromosome 90: Score - 0.0   Time: 3707.6 * Chromosome 91: Score - 0.0   Time: 3912. ...
# Best Chromosome for Run 1 -> Time Alive: 673.6    High Score: 483.0
# Chromosome 1: Score - 512.4   Time: 2762.8 * Chromosome 2: Score - 483.0   Time: 673.6 * Chromosome 3: Score - 483.0   Time: 1739.6 * Chromosome 4: Score - 474.6   Time: 624.6 * Chromosome 5: Score - 474.6   Time: 647.8 * Chromosome 6: Score - 470.4   Time: 629.8 * Chromosome 7: Score - 466.2   Time: 656.0 * Chromosome 8: Score - 466.2   Time: 678.2 * Chromosome 9: Score - 462.0   Time: 654.2 * Chromosome 10: Score - 462.0   Time: 927.6 * Chromosome 11: Score - 453.6   Time: 619.0 * Chromosome 12: Score - 453.6   Time: 639.4 * Chromosome 13: Score - 449.4   Time: 858.2 * Chromosome 14: Score - 445.2   Time: 638.4 * Chromosome 15: Score - 445.2   Time: 641.4 * Chromosome 16: Score - 445.2   Time: 643.6 * Chromosome 17: Score - 445.2   Time: 647.2 * Chromosome 18: Score - 445.2   Time: 1276.8 * Chromosome 19: Score - 441.0   Time: 621.4 * Chromosome 20: Score - 441.0   Time: 631.4 * Chromosome 21: Score - 432.6   Time: 647.8 * Chromosome 22: Score - 428.4   Time: 579.4 * Chromosome 23: Score - 428.4   Time: 592.4 * Chromosome 24: Score - 428.4   Time: 596.6 * Chromosome 25: Score - 428.4   Time: 635.2 * Chromosome 26: Score - 428.4   Time: 713.8 * Chromosome 27: Score - 424.2   Time: 635.0 * Chromosome 28: Score - 424.2   Time: 648.6 * Chromosome 29: Score - 420.0   Time: 593.4 * Chromosome 30: Score - 420.0   Time: 607.8 * Chromosome 31: Score - 415.8   Time: 610.4 * Chromosome 32: Score - 415.8   Time: 614.4 * Chromosome 33: Score - 411.6   Time: 621.0 * Chromosome 34: Score - 411.6   Time: 623.8 * Chromosome 35: Score - 411.6   Time: 625.2 * Chromosome 36: Score - 407.4   Time: 624.6 * Chromosome 37: Score - 403.2   Time: 604.8 * Chromosome 38: Score - 403.2   Time: 628.2 * Chromosome 39: Score - 399.0   Time: 570.4 * Chromosome 40: Score - 399.0   Time: 583.8 * Chromosome 41: Score - 399.0   Time: 2385.6 * Chromosome 42: Score - 390.6   Time: 547.6 * Chromosome 43: Score - 382.2   Time: 573.2 * Chromosome 44: Score - 378.0   Time: 577.4 * Chromosome 45: Score - 378.0   Time: 586.8 * Chromosome 46: Score - 378.0   Time: 777.4 * Chromosome 47: Score - 373.8   Time: 573.6 * Chromosome 48: Score - 373.8   Time: 579.0 * Chromosome 49: Score - 373.8   Time: 599.4 * Chromosome 50: Score - 365.4   Time: 532.6 * Chromosome 51: Score - 365.4   Time: 545.2 * Chromosome 52: Score - 361.2   Time: 582.2 * Chromosome 53: Score - 361.2   Time: 756.6 * Chromosome 54: Score - 357.0   Time: 592.4 * Chromosome 55: Score - 352.8   Time: 550.4 * Chromosome 56: Score - 340.2   Time: 506.0 * Chromosome 57: Score - 340.2   Time: 514.8 * Chromosome 58: Score - 336.0   Time: 507.8 * Chromosome 59: Score - 331.8   Time: 571.4 * Chromosome 60: Score - 327.6   Time: 596.6 * Chromosome 61: Score - 315.0   Time: 5423.4 * Chromosome 62: Score - 306.6   Time: 478.8 * Chromosome 63: Score - 298.2   Time: 483.2 * Chromosome 64: Score - 285.6   Time: 503.6 * Chromosome 65: Score - 281.4   Time: 475.6 * Chromosome 66: Score - 168.0   Time: 3112.2 * Chromosome 67: Score - 126.0   Time: 1421.2 * Chromosome 68: Score - 121.8   Time: 1569.8 * Chromosome 69: Score - 92.4   Time: 3714.0 * Chromosome 70: Score - 42.0   Time: 7106.0 * Chromosome 71: Score - 37.8   Time: 420.2 * Chromosome 72: Score - 33.6   Time: 341.6 * Chromosome 73: Score - 8.4   Time: 325.4 * Chromosome 74: Score - 0.0   Time: 259.6 * Chromosome 75: Score - 0.0   Time: 286.0 * Chromosome 76: Score - 0.0   Time: 305.2 * Chromosome 77: Score - 0.0   Time: 374.2 * Chromosome 78: Score - 0.0   Time: 450.0 * Chromosome 79: Score - 0.0   Time: 646.0 * Chromosome 80: Score - 0.0   Time: 1019.6 * Chromosome 81: Score - 0.0   Time: 1326.8 * Chromosome 82: Score - 0.0   Time: 1563.6 * Chromosome 83: Score - 0.0   Time: 1865.4 * Chromosome 84: Score - 0.0   Time: 2171.6 * Chromosome 85: Score - 0.0   Time: 2568.4 * Chromosome 86: Score - 0.0   Time: 2670.8 * Chromosome 87: Score - 0.0   Time: 2728.4 * Chromosome 88: Score - 0.0   Time: 3182.8 * Chromosome 89: Score - 0.0   Time: 3387.6 * Chromosome 90: Score - ...
# Best Chromosome for Run 2 -> Time Alive: 2762.8    High Score: 512.4
# Chromosome 1: Score - 541.8   Time: 2007.0 * Chromosome 2: Score - 525.0   Time: 1081.2 * Chromosome 3: Score - 516.6   Time: 682.6 * Chromosome 4: Score - 512.4   Time: 2762.8 * Chromosome 5: Score - 487.2   Time: 628.2 * Chromosome 6: Score - 487.2   Time: 670.6 * Chromosome 7: Score - 487.2   Time: 708.4 * Chromosome 8: Score - 483.0   Time: 673.6 * Chromosome 9: Score - 483.0   Time: 677.2 * Chromosome 10: Score - 483.0   Time: 1739.6 * Chromosome 11: Score - 478.8   Time: 666.8 * Chromosome 12: Score - 474.6   Time: 622.0 * Chromosome 13: Score - 474.6   Time: 647.8 * Chromosome 14: Score - 470.4   Time: 629.8 * Chromosome 15: Score - 470.4   Time: 663.0 * Chromosome 16: Score - 470.4   Time: 668.8 * Chromosome 17: Score - 466.2   Time: 656.0 * Chromosome 18: Score - 466.2   Time: 678.2 * Chromosome 19: Score - 462.0   Time: 654.2 * Chromosome 20: Score - 462.0   Time: 927.6 * Chromosome 21: Score - 457.8   Time: 590.0 * Chromosome 22: Score - 453.6   Time: 619.0 * Chromosome 23: Score - 453.6   Time: 639.4 * Chromosome 24: Score - 449.4   Time: 858.2 * Chromosome 25: Score - 449.4   Time: 1184.6 * Chromosome 26: Score - 445.2   Time: 638.4 * Chromosome 27: Score - 445.2   Time: 641.4 * Chromosome 28: Score - 445.2   Time: 643.6 * Chromosome 29: Score - 445.2   Time: 647.2 * Chromosome 30: Score - 441.0   Time: 565.2 * Chromosome 31: Score - 441.0   Time: 621.4 * Chromosome 32: Score - 441.0   Time: 631.4 * Chromosome 33: Score - 432.6   Time: 639.0 * Chromosome 34: Score - 424.2   Time: 608.2 * Chromosome 35: Score - 424.2   Time: 609.2 * Chromosome 36: Score - 424.2   Time: 625.6 * Chromosome 37: Score - 424.2   Time: 629.8 * Chromosome 38: Score - 424.2   Time: 797.6 * Chromosome 39: Score - 420.0   Time: 607.4 * Chromosome 40: Score - 420.0   Time: 625.4 * Chromosome 41: Score - 420.0   Time: 679.6 * Chromosome 42: Score - 415.8   Time: 582.8 * Chromosome 43: Score - 415.8   Time: 605.4 * Chromosome 44: Score - 415.8   Time: 608.2 * Chromosome 45: Score - 415.8   Time: 610.6 * Chromosome 46: Score - 415.8   Time: 644.8 * Chromosome 47: Score - 411.6   Time: 598.6 * Chromosome 48: Score - 411.6   Time: 602.2 * Chromosome 49: Score - 411.6   Time: 611.4 * Chromosome 50: Score - 411.6   Time: 632.0 * Chromosome 51: Score - 407.4   Time: 593.4 * Chromosome 52: Score - 407.4   Time: 618.6 * Chromosome 53: Score - 407.4   Time: 632.8 * Chromosome 54: Score - 403.2   Time: 578.8 * Chromosome 55: Score - 403.2   Time: 585.8 * Chromosome 56: Score - 403.2   Time: 599.8 * Chromosome 57: Score - 403.2   Time: 602.2 * Chromosome 58: Score - 403.2   Time: 622.2 * Chromosome 59: Score - 403.2   Time: 633.0 * Chromosome 60: Score - 403.2   Time: 637.6 * Chromosome 61: Score - 386.4   Time: 607.4 * Chromosome 62: Score - 386.4   Time: 651.0 * Chromosome 63: Score - 382.2   Time: 553.4 * Chromosome 64: Score - 382.2   Time: 562.2 * Chromosome 65: Score - 382.2   Time: 608.6 * Chromosome 66: Score - 378.0   Time: 511.8 * Chromosome 67: Score - 378.0   Time: 551.6 * Chromosome 68: Score - 378.0   Time: 596.4 * Chromosome 69: Score - 378.0   Time: 602.8 * Chromosome 70: Score - 373.8   Time: 589.0 * Chromosome 71: Score - 369.6   Time: 549.0 * Chromosome 72: Score - 369.6   Time: 555.0 * Chromosome 73: Score - 369.6   Time: 572.6 * Chromosome 74: Score - 365.4   Time: 588.2 * Chromosome 75: Score - 361.2   Time: 605.8 * Chromosome 76: Score - 357.0   Time: 520.6 * Chromosome 77: Score - 357.0   Time: 563.4 * Chromosome 78: Score - 357.0   Time: 563.6 * Chromosome 79: Score - 357.0   Time: 608.6 * Chromosome 80: Score - 352.8   Time: 632.6 * Chromosome 81: Score - 348.6   Time: 544.2 * Chromosome 82: Score - 348.6   Time: 545.4 * Chromosome 83: Score - 348.6   Time: 571.0 * Chromosome 84: Score - 348.6   Time: 573.2 * Chromosome 85: Score - 348.6   Time: 580.4 * Chromosome 86: Score - 348.6   Time: 652.4 * Chromosome 87: Score - 344.4   Time: 553.0 * Chromosome 88: Score - 344.4   Time: 579.6 * Chromosome 89: Score - 340.2   Time: 570.4 * ...
# Best Chromosome for Run 3 -> Time Alive: 2007.0    High Score: 541.8
# Chromosome 1: Score - 541.8   Time: 1546.8 * Chromosome 2: Score - 525.0   Time: 1081.2 * Chromosome 3: Score - 516.6   Time: 682.6 * Chromosome 4: Score - 516.6   Time: 916.4 * Chromosome 5: Score - 512.4   Time: 2762.8 * Chromosome 6: Score - 487.2   Time: 628.2 * Chromosome 7: Score - 487.2   Time: 670.6 * Chromosome 8: Score - 487.2   Time: 708.4 * Chromosome 9: Score - 483.0   Time: 673.6 * Chromosome 10: Score - 483.0   Time: 677.2 * Chromosome 11: Score - 478.8   Time: 649.0 * Chromosome 12: Score - 478.8   Time: 666.8 * Chromosome 13: Score - 474.6   Time: 622.0 * Chromosome 14: Score - 474.6   Time: 657.6 * Chromosome 15: Score - 470.4   Time: 629.8 * Chromosome 16: Score - 470.4   Time: 657.6 * Chromosome 17: Score - 470.4   Time: 663.0 * Chromosome 18: Score - 470.4   Time: 668.8 * Chromosome 19: Score - 470.4   Time: 669.8 * Chromosome 20: Score - 470.4   Time: 2944.8 * Chromosome 21: Score - 466.2   Time: 673.8 * Chromosome 22: Score - 466.2   Time: 676.6 * Chromosome 23: Score - 466.2   Time: 678.2 * Chromosome 24: Score - 466.2   Time: 695.2 * Chromosome 25: Score - 462.0   Time: 654.2 * Chromosome 26: Score - 462.0   Time: 658.2 * Chromosome 27: Score - 462.0   Time: 662.6 * Chromosome 28: Score - 457.8   Time: 618.8 * Chromosome 29: Score - 457.8   Time: 625.0 * Chromosome 30: Score - 457.8   Time: 625.6 * Chromosome 31: Score - 457.8   Time: 656.4 * Chromosome 32: Score - 453.6   Time: 620.2 * Chromosome 33: Score - 453.6   Time: 639.2 * Chromosome 34: Score - 449.4   Time: 612.2 * Chromosome 35: Score - 449.4   Time: 657.4 * Chromosome 36: Score - 445.2   Time: 628.4 * Chromosome 37: Score - 445.2   Time: 649.6 * Chromosome 38: Score - 441.0   Time: 625.2 * Chromosome 39: Score - 441.0   Time: 628.8 * Chromosome 40: Score - 441.0   Time: 631.4 * Chromosome 41: Score - 436.8   Time: 606.2 * Chromosome 42: Score - 436.8   Time: 632.0 * Chromosome 43: Score - 428.4   Time: 598.8 * Chromosome 44: Score - 428.4   Time: 625.0 * Chromosome 45: Score - 428.4   Time: 657.4 * Chromosome 46: Score - 424.2   Time: 580.2 * Chromosome 47: Score - 424.2   Time: 658.2 * Chromosome 48: Score - 424.2   Time: 663.6 * Chromosome 49: Score - 420.0   Time: 614.0 * Chromosome 50: Score - 415.8   Time: 585.4 * Chromosome 51: Score - 415.8   Time: 592.2 * Chromosome 52: Score - 415.8   Time: 656.2 * Chromosome 53: Score - 411.6   Time: 605.6 * Chromosome 54: Score - 411.6   Time: 619.0 * Chromosome 55: Score - 407.4   Time: 582.8 * Chromosome 56: Score - 407.4   Time: 640.6 * Chromosome 57: Score - 407.4   Time: 660.6 * Chromosome 58: Score - 403.2   Time: 575.2 * Chromosome 59: Score - 403.2   Time: 615.4 * Chromosome 60: Score - 403.2   Time: 615.6 * Chromosome 61: Score - 403.2   Time: 640.4 * Chromosome 62: Score - 399.0   Time: 603.2 * Chromosome 63: Score - 390.6   Time: 600.0 * Chromosome 64: Score - 386.4   Time: 524.8 * Chromosome 65: Score - 386.4   Time: 548.2 * Chromosome 66: Score - 382.2   Time: 581.2 * Chromosome 67: Score - 382.2   Time: 710.6 * Chromosome 68: Score - 378.0   Time: 543.2 * Chromosome 69: Score - 373.8   Time: 566.6 * Chromosome 70: Score - 369.6   Time: 540.6 * Chromosome 71: Score - 369.6   Time: 564.2 * Chromosome 72: Score - 369.6   Time: 569.0 * Chromosome 73: Score - 365.4   Time: 557.8 * Chromosome 74: Score - 361.2   Time: 542.0 * Chromosome 75: Score - 357.0   Time: 552.8 * Chromosome 76: Score - 357.0   Time: 595.6 * Chromosome 77: Score - 352.8   Time: 519.0 * Chromosome 78: Score - 352.8   Time: 531.4 * Chromosome 79: Score - 352.8   Time: 615.4 * Chromosome 80: Score - 352.8   Time: 656.2 * Chromosome 81: Score - 348.6   Time: 527.8 * Chromosome 82: Score - 344.4   Time: 511.2 * Chromosome 83: Score - 344.4   Time: 573.8 * Chromosome 84: Score - 340.2   Time: 688.4 * Chromosome 85: Score - 336.0   Time: 484.0 * Chromosome 86: Score - 336.0   Time: 501.2 * Chromosome 87: Score - 331.8   Time: 590.0 * Chromosome 88: Score - 323.4   Time: 734.0 * Chromosome 89: Score - 319.2   Time: 583.4 *  ...
# Best Chromosome for Run 4 -> Time Alive: 2007.0    High Score: 541.8
# Chromosome 1: Score - 672.0   Time: 1766.8 * Chromosome 2: Score - 613.2   Time: 1647.2 * Chromosome 3: Score - 567.0   Time: 1624.4 * Chromosome 4: Score - 546.0   Time: 1744.0 * Chromosome 5: Score - 541.8   Time: 1546.8 * Chromosome 6: Score - 525.0   Time: 1081.2 * Chromosome 7: Score - 520.8   Time: 676.4 * Chromosome 8: Score - 516.6   Time: 708.4 * Chromosome 9: Score - 516.6   Time: 1401.2 * Chromosome 10: Score - 512.4   Time: 2762.8 * Chromosome 11: Score - 495.6   Time: 647.8 * Chromosome 12: Score - 487.2   Time: 628.2 * Chromosome 13: Score - 487.2   Time: 670.6 * Chromosome 14: Score - 487.2   Time: 708.4 * Chromosome 15: Score - 483.0   Time: 641.0 * Chromosome 16: Score - 483.0   Time: 670.4 * Chromosome 17: Score - 483.0   Time: 673.6 * Chromosome 18: Score - 483.0   Time: 677.2 * Chromosome 19: Score - 483.0   Time: 679.8 * Chromosome 20: Score - 483.0   Time: 687.8 * Chromosome 21: Score - 478.8   Time: 649.0 * Chromosome 22: Score - 478.8   Time: 666.8 * Chromosome 23: Score - 474.6   Time: 657.6 * Chromosome 24: Score - 474.6   Time: 1144.2 * Chromosome 25: Score - 470.4   Time: 629.8 * Chromosome 26: Score - 470.4   Time: 663.0 * Chromosome 27: Score - 470.4   Time: 668.8 * Chromosome 28: Score - 470.4   Time: 669.8 * Chromosome 29: Score - 470.4   Time: 2944.8 * Chromosome 30: Score - 466.2   Time: 676.6 * Chromosome 31: Score - 462.0   Time: 638.0 * Chromosome 32: Score - 457.8   Time: 608.2 * Chromosome 33: Score - 457.8   Time: 621.6 * Chromosome 34: Score - 457.8   Time: 621.8 * Chromosome 35: Score - 457.8   Time: 667.0 * Chromosome 36: Score - 453.6   Time: 627.6 * Chromosome 37: Score - 449.4   Time: 618.6 * Chromosome 38: Score - 449.4   Time: 627.8 * Chromosome 39: Score - 449.4   Time: 703.6 * Chromosome 40: Score - 449.4   Time: 2254.2 * Chromosome 41: Score - 445.2   Time: 624.4 * Chromosome 42: Score - 441.0   Time: 637.2 * Chromosome 43: Score - 441.0   Time: 644.0 * Chromosome 44: Score - 436.8   Time: 575.2 * Chromosome 45: Score - 436.8   Time: 599.6 * Chromosome 46: Score - 436.8   Time: 615.0 * Chromosome 47: Score - 436.8   Time: 669.0 * Chromosome 48: Score - 432.6   Time: 809.6 * Chromosome 49: Score - 428.4   Time: 587.0 * Chromosome 50: Score - 428.4   Time: 597.2 * Chromosome 51: Score - 428.4   Time: 636.2 * Chromosome 52: Score - 428.4   Time: 646.4 * Chromosome 53: Score - 424.2   Time: 601.0 * Chromosome 54: Score - 424.2   Time: 632.0 * Chromosome 55: Score - 424.2   Time: 637.0 * Chromosome 56: Score - 424.2   Time: 647.6 * Chromosome 57: Score - 420.0   Time: 595.2 * Chromosome 58: Score - 420.0   Time: 605.0 * Chromosome 59: Score - 415.8   Time: 600.2 * Chromosome 60: Score - 415.8   Time: 608.8 * Chromosome 61: Score - 415.8   Time: 644.0 * Chromosome 62: Score - 411.6   Time: 618.0 * Chromosome 63: Score - 407.4   Time: 1490.0 * Chromosome 64: Score - 403.2   Time: 596.6 * Chromosome 65: Score - 403.2   Time: 628.4 * Chromosome 66: Score - 403.2   Time: 631.8 * Chromosome 67: Score - 390.6   Time: 599.0 * Chromosome 68: Score - 390.6   Time: 620.2 * Chromosome 69: Score - 390.6   Time: 698.2 * Chromosome 70: Score - 382.2   Time: 544.4 * Chromosome 71: Score - 382.2   Time: 560.6 * Chromosome 72: Score - 382.2   Time: 637.2 * Chromosome 73: Score - 378.0   Time: 575.8 * Chromosome 74: Score - 378.0   Time: 602.0 * Chromosome 75: Score - 378.0   Time: 609.2 * Chromosome 76: Score - 378.0   Time: 615.6 * Chromosome 77: Score - 373.8   Time: 538.8 * Chromosome 78: Score - 373.8   Time: 554.0 * Chromosome 79: Score - 369.6   Time: 515.2 * Chromosome 80: Score - 369.6   Time: 525.0 * Chromosome 81: Score - 369.6   Time: 548.6 * Chromosome 82: Score - 369.6   Time: 568.4 * Chromosome 83: Score - 365.4   Time: 553.0 * Chromosome 84: Score - 361.2   Time: 589.8 * Chromosome 85: Score - 361.2   Time: 620.2 * Chromosome 86: Score - 361.2   Time: 723.0 * Chromosome 87: Score - 357.0   Time: 626.4 * Chromosome 88: Score - 348.6   Time: 561.4 * Chromosome 89: Score - 344.4   Time:  ...
# Best Chromosome for Run 5 -> Time Alive: 1766.8    High Score: 672.0
# Chromosome 1: Score - 672.0   Time: 1766.8 * Chromosome 2: Score - 613.2   Time: 1647.2 * Chromosome 3: Score - 567.0   Time: 957.4 * Chromosome 4: Score - 567.0   Time: 1624.4 * Chromosome 5: Score - 550.2   Time: 1868.6 * Chromosome 6: Score - 546.0   Time: 1744.0 * Chromosome 7: Score - 541.8   Time: 1546.8 * Chromosome 8: Score - 533.4   Time: 1737.6 * Chromosome 9: Score - 525.0   Time: 1081.2 * Chromosome 10: Score - 525.0   Time: 1938.2 * Chromosome 11: Score - 520.8   Time: 676.4 * Chromosome 12: Score - 516.6   Time: 708.4 * Chromosome 13: Score - 516.6   Time: 1401.2 * Chromosome 14: Score - 512.4   Time: 2762.8 * Chromosome 15: Score - 504.0   Time: 703.2 * Chromosome 16: Score - 499.8   Time: 807.4 * Chromosome 17: Score - 495.6   Time: 647.8 * Chromosome 18: Score - 495.6   Time: 3539.2 * Chromosome 19: Score - 487.2   Time: 628.2 * Chromosome 20: Score - 487.2   Time: 670.6 * Chromosome 21: Score - 487.2   Time: 708.4 * Chromosome 22: Score - 487.2   Time: 867.0 * Chromosome 23: Score - 483.0   Time: 641.0 * Chromosome 24: Score - 483.0   Time: 650.8 * Chromosome 25: Score - 483.0   Time: 670.4 * Chromosome 26: Score - 483.0   Time: 673.6 * Chromosome 27: Score - 483.0   Time: 677.2 * Chromosome 28: Score - 483.0   Time: 679.8 * Chromosome 29: Score - 483.0   Time: 687.8 * Chromosome 30: Score - 478.8   Time: 686.4 * Chromosome 31: Score - 474.6   Time: 630.2 * Chromosome 32: Score - 466.2   Time: 640.4 * Chromosome 33: Score - 466.2   Time: 661.0 * Chromosome 34: Score - 462.0   Time: 628.4 * Chromosome 35: Score - 457.8   Time: 644.4 * Chromosome 36: Score - 453.6   Time: 589.8 * Chromosome 37: Score - 453.6   Time: 641.6 * Chromosome 38: Score - 453.6   Time: 643.8 * Chromosome 39: Score - 449.4   Time: 624.6 * Chromosome 40: Score - 449.4   Time: 625.4 * Chromosome 41: Score - 445.2   Time: 631.0 * Chromosome 42: Score - 445.2   Time: 644.6 * Chromosome 43: Score - 445.2   Time: 667.2 * Chromosome 44: Score - 441.0   Time: 902.0 * Chromosome 45: Score - 436.8   Time: 934.2 * Chromosome 46: Score - 432.6   Time: 639.6 * Chromosome 47: Score - 428.4   Time: 569.2 * Chromosome 48: Score - 428.4   Time: 639.8 * Chromosome 49: Score - 428.4   Time: 674.2 * Chromosome 50: Score - 424.2   Time: 593.2 * Chromosome 51: Score - 424.2   Time: 606.2 * Chromosome 52: Score - 424.2   Time: 624.2 * Chromosome 53: Score - 424.2   Time: 658.6 * Chromosome 54: Score - 420.0   Time: 570.8 * Chromosome 55: Score - 420.0   Time: 606.0 * Chromosome 56: Score - 415.8   Time: 589.0 * Chromosome 57: Score - 415.8   Time: 665.2 * Chromosome 58: Score - 411.6   Time: 570.2 * Chromosome 59: Score - 411.6   Time: 586.6 * Chromosome 60: Score - 411.6   Time: 588.2 * Chromosome 61: Score - 411.6   Time: 599.8 * Chromosome 62: Score - 411.6   Time: 628.0 * Chromosome 63: Score - 411.6   Time: 631.0 * Chromosome 64: Score - 411.6   Time: 636.6 * Chromosome 65: Score - 411.6   Time: 638.2 * Chromosome 66: Score - 407.4   Time: 641.6 * Chromosome 67: Score - 403.2   Time: 563.6 * Chromosome 68: Score - 403.2   Time: 572.6 * Chromosome 69: Score - 403.2   Time: 590.2 * Chromosome 70: Score - 403.2   Time: 596.8 * Chromosome 71: Score - 403.2   Time: 614.2 * Chromosome 72: Score - 399.0   Time: 577.2 * Chromosome 73: Score - 399.0   Time: 607.4 * Chromosome 74: Score - 394.8   Time: 588.8 * Chromosome 75: Score - 394.8   Time: 647.0 * Chromosome 76: Score - 390.6   Time: 538.2 * Chromosome 77: Score - 390.6   Time: 568.8 * Chromosome 78: Score - 390.6   Time: 631.8 * Chromosome 79: Score - 386.4   Time: 585.2 * Chromosome 80: Score - 386.4   Time: 621.8 * Chromosome 81: Score - 378.0   Time: 576.6 * Chromosome 82: Score - 369.6   Time: 544.6 * Chromosome 83: Score - 369.6   Time: 599.2 * Chromosome 84: Score - 357.0   Time: 551.0 * Chromosome 85: Score - 352.8   Time: 522.6 * Chromosome 86: Score - 352.8   Time: 589.6 * Chromosome 87: Score - 352.8   Time: 589.8 * Chromosome 88: Score - 340.2   Time: 524.8 * Chromosome 89: Score - 336.0   Time:  ...
# Best Chromosome for Run 6 -> Time Alive: 1766.8    High Score: 672.0
# Chromosome 1: Score - 672.0   Time: 1766.8 * Chromosome 2: Score - 604.8   Time: 1190.8 * Chromosome 3: Score - 588.0   Time: 1025.6 * Chromosome 4: Score - 567.0   Time: 957.4 * Chromosome 5: Score - 550.2   Time: 1868.6 * Chromosome 6: Score - 541.8   Time: 1546.8 * Chromosome 7: Score - 533.4   Time: 1737.6 * Chromosome 8: Score - 533.4   Time: 3939.2 * Chromosome 9: Score - 525.0   Time: 1081.2 * Chromosome 10: Score - 525.0   Time: 1938.2 * Chromosome 11: Score - 520.8   Time: 676.4 * Chromosome 12: Score - 516.6   Time: 708.4 * Chromosome 13: Score - 516.6   Time: 1401.2 * Chromosome 14: Score - 512.4   Time: 2762.8 * Chromosome 15: Score - 504.0   Time: 703.2 * Chromosome 16: Score - 499.8   Time: 669.6 * Chromosome 17: Score - 499.8   Time: 807.4 * Chromosome 18: Score - 495.6   Time: 647.8 * Chromosome 19: Score - 495.6   Time: 3539.2 * Chromosome 20: Score - 487.2   Time: 628.2 * Chromosome 21: Score - 487.2   Time: 663.6 * Chromosome 22: Score - 487.2   Time: 670.6 * Chromosome 23: Score - 478.8   Time: 727.6 * Chromosome 24: Score - 474.6   Time: 631.8 * Chromosome 25: Score - 474.6   Time: 672.4 * Chromosome 26: Score - 466.2   Time: 628.6 * Chromosome 27: Score - 466.2   Time: 636.6 * Chromosome 28: Score - 462.0   Time: 638.8 * Chromosome 29: Score - 462.0   Time: 647.6 * Chromosome 30: Score - 457.8   Time: 651.0 * Chromosome 31: Score - 457.8   Time: 2833.4 * Chromosome 32: Score - 453.6   Time: 609.2 * Chromosome 33: Score - 453.6   Time: 659.6 * Chromosome 34: Score - 453.6   Time: 1002.8 * Chromosome 35: Score - 449.4   Time: 632.0 * Chromosome 36: Score - 445.2   Time: 633.8 * Chromosome 37: Score - 445.2   Time: 654.2 * Chromosome 38: Score - 445.2   Time: 832.4 * Chromosome 39: Score - 441.0   Time: 632.0 * Chromosome 40: Score - 436.8   Time: 596.0 * Chromosome 41: Score - 436.8   Time: 628.6 * Chromosome 42: Score - 436.8   Time: 638.2 * Chromosome 43: Score - 436.8   Time: 674.6 * Chromosome 44: Score - 432.6   Time: 624.0 * Chromosome 45: Score - 424.2   Time: 596.2 * Chromosome 46: Score - 424.2   Time: 611.8 * Chromosome 47: Score - 420.0   Time: 615.6 * Chromosome 48: Score - 415.8   Time: 620.2 * Chromosome 49: Score - 411.6   Time: 569.8 * Chromosome 50: Score - 407.4   Time: 549.6 * Chromosome 51: Score - 407.4   Time: 628.2 * Chromosome 52: Score - 403.2   Time: 549.2 * Chromosome 53: Score - 403.2   Time: 609.8 * Chromosome 54: Score - 403.2   Time: 635.2 * Chromosome 55: Score - 399.0   Time: 569.4 * Chromosome 56: Score - 399.0   Time: 668.6 * Chromosome 57: Score - 399.0   Time: 675.4 * Chromosome 58: Score - 394.8   Time: 571.4 * Chromosome 59: Score - 390.6   Time: 571.6 * Chromosome 60: Score - 390.6   Time: 595.6 * Chromosome 61: Score - 390.6   Time: 605.2 * Chromosome 62: Score - 386.4   Time: 563.4 * Chromosome 63: Score - 386.4   Time: 591.6 * Chromosome 64: Score - 386.4   Time: 593.0 * Chromosome 65: Score - 386.4   Time: 598.4 * Chromosome 66: Score - 386.4   Time: 611.8 * Chromosome 67: Score - 378.0   Time: 530.6 * Chromosome 68: Score - 378.0   Time: 561.2 * Chromosome 69: Score - 378.0   Time: 596.4 * Chromosome 70: Score - 373.8   Time: 589.6 * Chromosome 71: Score - 373.8   Time: 596.4 * Chromosome 72: Score - 369.6   Time: 558.0 * Chromosome 73: Score - 369.6   Time: 564.4 * Chromosome 74: Score - 365.4   Time: 542.8 * Chromosome 75: Score - 365.4   Time: 591.2 * Chromosome 76: Score - 365.4   Time: 615.8 * Chromosome 77: Score - 365.4   Time: 622.0 * Chromosome 78: Score - 365.4   Time: 727.8 * Chromosome 79: Score - 361.2   Time: 531.2 * Chromosome 80: Score - 361.2   Time: 563.4 * Chromosome 81: Score - 361.2   Time: 611.2 * Chromosome 82: Score - 357.0   Time: 508.8 * Chromosome 83: Score - 352.8   Time: 541.6 * Chromosome 84: Score - 348.6   Time: 568.4 * Chromosome 85: Score - 344.4   Time: 544.6 * Chromosome 86: Score - 344.4   Time: 550.2 * Chromosome 87: Score - 344.4   Time: 636.8 * Chromosome 88: Score - 340.2   Time: 536.0 * Chromosome 89: Score - 336.0   Time ...
# Best Chromosome for Run 7 -> Time Alive: 1766.8    High Score: 672.0
# Chromosome 1: Score - 672.0   Time: 1766.8 * Chromosome 2: Score - 667.8   Time: 2301.0 * Chromosome 3: Score - 617.4   Time: 1468.0 * Chromosome 4: Score - 592.2   Time: 2304.0 * Chromosome 5: Score - 588.0   Time: 1025.6 * Chromosome 6: Score - 588.0   Time: 1819.2 * Chromosome 7: Score - 567.0   Time: 957.4 * Chromosome 8: Score - 550.2   Time: 1868.6 * Chromosome 9: Score - 541.8   Time: 1546.8 * Chromosome 10: Score - 533.4   Time: 1737.6 * Chromosome 11: Score - 533.4   Time: 3939.2 * Chromosome 12: Score - 525.0   Time: 1081.2 * Chromosome 13: Score - 525.0   Time: 1938.2 * Chromosome 14: Score - 520.8   Time: 676.4 * Chromosome 15: Score - 520.8   Time: 4066.8 * Chromosome 16: Score - 516.6   Time: 1401.2 * Chromosome 17: Score - 512.4   Time: 2762.8 * Chromosome 18: Score - 508.2   Time: 687.6 * Chromosome 19: Score - 504.0   Time: 664.0 * Chromosome 20: Score - 504.0   Time: 703.2 * Chromosome 21: Score - 499.8   Time: 669.6 * Chromosome 22: Score - 499.8   Time: 702.4 * Chromosome 23: Score - 495.6   Time: 647.8 * Chromosome 24: Score - 495.6   Time: 3539.2 * Chromosome 25: Score - 491.4   Time: 647.0 * Chromosome 26: Score - 487.2   Time: 628.2 * Chromosome 27: Score - 487.2   Time: 680.6 * Chromosome 28: Score - 487.2   Time: 3276.2 * Chromosome 29: Score - 483.0   Time: 652.4 * Chromosome 30: Score - 474.6   Time: 641.0 * Chromosome 31: Score - 470.4   Time: 648.0 * Chromosome 32: Score - 466.2   Time: 655.6 * Chromosome 33: Score - 466.2   Time: 2307.0 * Chromosome 34: Score - 462.0   Time: 621.2 * Chromosome 35: Score - 462.0   Time: 660.0 * Chromosome 36: Score - 457.8   Time: 646.8 * Chromosome 37: Score - 457.8   Time: 673.2 * Chromosome 38: Score - 453.6   Time: 631.2 * Chromosome 39: Score - 453.6   Time: 656.6 * Chromosome 40: Score - 449.4   Time: 615.8 * Chromosome 41: Score - 449.4   Time: 666.2 * Chromosome 42: Score - 445.2   Time: 622.6 * Chromosome 43: Score - 445.2   Time: 628.6 * Chromosome 44: Score - 445.2   Time: 656.2 * Chromosome 45: Score - 441.0   Time: 612.0 * Chromosome 46: Score - 436.8   Time: 569.0 * Chromosome 47: Score - 432.6   Time: 640.2 * Chromosome 48: Score - 432.6   Time: 660.4 * Chromosome 49: Score - 432.6   Time: 679.8 * Chromosome 50: Score - 428.4   Time: 580.6 * Chromosome 51: Score - 428.4   Time: 581.8 * Chromosome 52: Score - 428.4   Time: 633.8 * Chromosome 53: Score - 428.4   Time: 653.6 * Chromosome 54: Score - 424.2   Time: 599.4 * Chromosome 55: Score - 424.2   Time: 624.2 * Chromosome 56: Score - 424.2   Time: 628.8 * Chromosome 57: Score - 424.2   Time: 629.2 * Chromosome 58: Score - 415.8   Time: 587.6 * Chromosome 59: Score - 415.8   Time: 603.0 * Chromosome 60: Score - 415.8   Time: 603.0 * Chromosome 61: Score - 415.8   Time: 614.8 * Chromosome 62: Score - 415.8   Time: 623.2 * Chromosome 63: Score - 411.6   Time: 551.2 * Chromosome 64: Score - 411.6   Time: 624.0 * Chromosome 65: Score - 411.6   Time: 641.4 * Chromosome 66: Score - 407.4   Time: 566.8 * Chromosome 67: Score - 407.4   Time: 582.0 * Chromosome 68: Score - 403.2   Time: 564.0 * Chromosome 69: Score - 403.2   Time: 613.6 * Chromosome 70: Score - 399.0   Time: 596.6 * Chromosome 71: Score - 394.8   Time: 583.6 * Chromosome 72: Score - 394.8   Time: 586.6 * Chromosome 73: Score - 394.8   Time: 587.0 * Chromosome 74: Score - 394.8   Time: 596.4 * Chromosome 75: Score - 394.8   Time: 612.6 * Chromosome 76: Score - 390.6   Time: 555.6 * Chromosome 77: Score - 390.6   Time: 618.8 * Chromosome 78: Score - 386.4   Time: 585.8 * Chromosome 79: Score - 386.4   Time: 598.8 * Chromosome 80: Score - 382.2   Time: 517.0 * Chromosome 81: Score - 369.6   Time: 543.2 * Chromosome 82: Score - 369.6   Time: 717.6 * Chromosome 83: Score - 357.0   Time: 556.4 * Chromosome 84: Score - 357.0   Time: 577.4 * Chromosome 85: Score - 348.6   Time: 551.0 * Chromosome 86: Score - 340.2   Time: 522.8 * Chromosome 87: Score - 340.2   Time: 556.4 * Chromosome 88: Score - 336.0   Time: 508.6 * Chromosome 89: Score - 336.0    ...
# Best Chromosome for Run 8 -> Time Alive: 1766.8    High Score: 672.0
# Chromosome 1: Score - 672.0   Time: 1766.8 * Chromosome 2: Score - 667.8   Time: 2301.0 * Chromosome 3: Score - 651.0   Time: 1763.4 * Chromosome 4: Score - 617.4   Time: 1468.0 * Chromosome 5: Score - 592.2   Time: 2304.0 * Chromosome 6: Score - 588.0   Time: 1819.2 * Chromosome 7: Score - 554.4   Time: 1687.0 * Chromosome 8: Score - 550.2   Time: 1868.6 * Chromosome 9: Score - 541.8   Time: 1546.8 * Chromosome 10: Score - 533.4   Time: 1737.6 * Chromosome 11: Score - 533.4   Time: 3939.2 * Chromosome 12: Score - 525.0   Time: 1081.2 * Chromosome 13: Score - 520.8   Time: 676.4 * Chromosome 14: Score - 520.8   Time: 4066.8 * Chromosome 15: Score - 516.6   Time: 1401.2 * Chromosome 16: Score - 512.4   Time: 2762.8 * Chromosome 17: Score - 508.2   Time: 687.6 * Chromosome 18: Score - 504.0   Time: 664.0 * Chromosome 19: Score - 504.0   Time: 703.2 * Chromosome 20: Score - 495.6   Time: 638.6 * Chromosome 21: Score - 491.4   Time: 635.0 * Chromosome 22: Score - 487.2   Time: 671.0 * Chromosome 23: Score - 487.2   Time: 677.8 * Chromosome 24: Score - 483.0   Time: 705.0 * Chromosome 25: Score - 478.8   Time: 660.8 * Chromosome 26: Score - 474.6   Time: 637.4 * Chromosome 27: Score - 474.6   Time: 659.0 * Chromosome 28: Score - 466.2   Time: 666.6 * Chromosome 29: Score - 466.2   Time: 686.2 * Chromosome 30: Score - 462.0   Time: 630.6 * Chromosome 31: Score - 462.0   Time: 650.6 * Chromosome 32: Score - 462.0   Time: 670.2 * Chromosome 33: Score - 457.8   Time: 630.4 * Chromosome 34: Score - 457.8   Time: 638.0 * Chromosome 35: Score - 457.8   Time: 641.4 * Chromosome 36: Score - 457.8   Time: 895.6 * Chromosome 37: Score - 453.6   Time: 620.4 * Chromosome 38: Score - 449.4   Time: 606.0 * Chromosome 39: Score - 449.4   Time: 854.0 * Chromosome 40: Score - 445.2   Time: 630.0 * Chromosome 41: Score - 436.8   Time: 588.2 * Chromosome 42: Score - 436.8   Time: 613.4 * Chromosome 43: Score - 436.8   Time: 622.2 * Chromosome 44: Score - 436.8   Time: 643.8 * Chromosome 45: Score - 436.8   Time: 644.6 * Chromosome 46: Score - 424.2   Time: 582.2 * Chromosome 47: Score - 424.2   Time: 641.0 * Chromosome 48: Score - 424.2   Time: 641.2 * Chromosome 49: Score - 420.0   Time: 599.6 * Chromosome 50: Score - 415.8   Time: 593.2 * Chromosome 51: Score - 407.4   Time: 548.8 * Chromosome 52: Score - 407.4   Time: 643.8 * Chromosome 53: Score - 403.2   Time: 596.6 * Chromosome 54: Score - 403.2   Time: 610.0 * Chromosome 55: Score - 399.0   Time: 572.0 * Chromosome 56: Score - 394.8   Time: 642.8 * Chromosome 57: Score - 390.6   Time: 615.0 * Chromosome 58: Score - 382.2   Time: 606.2 * Chromosome 59: Score - 382.2   Time: 635.2 * Chromosome 60: Score - 382.2   Time: 2818.4 * Chromosome 61: Score - 378.0   Time: 526.2 * Chromosome 62: Score - 378.0   Time: 544.0 * Chromosome 63: Score - 378.0   Time: 562.8 * Chromosome 64: Score - 373.8   Time: 566.4 * Chromosome 65: Score - 373.8   Time: 567.4 * Chromosome 66: Score - 373.8   Time: 600.0 * Chromosome 67: Score - 369.6   Time: 558.6 * Chromosome 68: Score - 369.6   Time: 612.2 * Chromosome 69: Score - 365.4   Time: 559.2 * Chromosome 70: Score - 365.4   Time: 560.2 * Chromosome 71: Score - 365.4   Time: 567.6 * Chromosome 72: Score - 365.4   Time: 615.4 * Chromosome 73: Score - 365.4   Time: 949.0 * Chromosome 74: Score - 361.2   Time: 534.6 * Chromosome 75: Score - 357.0   Time: 553.8 * Chromosome 76: Score - 357.0   Time: 590.0 * Chromosome 77: Score - 352.8   Time: 614.4 * Chromosome 78: Score - 344.4   Time: 492.0 * Chromosome 79: Score - 340.2   Time: 514.2 * Chromosome 80: Score - 340.2   Time: 528.0 * Chromosome 81: Score - 340.2   Time: 544.8 * Chromosome 82: Score - 340.2   Time: 577.6 * Chromosome 83: Score - 336.0   Time: 544.6 * Chromosome 84: Score - 331.8   Time: 496.0 * Chromosome 85: Score - 331.8   Time: 629.8 * Chromosome 86: Score - 327.6   Time: 570.0 * Chromosome 87: Score - 323.4   Time: 487.6 * Chromosome 88: Score - 323.4   Time: 2702.8 * Chromosome 89: Score - 315.0   T ...
# Best Chromosome for Run 9 -> Time Alive: 1766.8    High Score: 672.0
# Chromosome 1: Score - 680.4   Time: 1810.0 * Chromosome 2: Score - 672.0   Time: 1766.8 * Chromosome 3: Score - 667.8   Time: 2301.0 * Chromosome 4: Score - 667.8   Time: 3339.8 * Chromosome 5: Score - 651.0   Time: 1308.8 * Chromosome 6: Score - 651.0   Time: 1763.4 * Chromosome 7: Score - 651.0   Time: 3939.0 * Chromosome 8: Score - 617.4   Time: 1468.0 * Chromosome 9: Score - 613.2   Time: 1168.2 * Chromosome 10: Score - 596.4   Time: 1018.0 * Chromosome 11: Score - 596.4   Time: 5555.2 * Chromosome 12: Score - 588.0   Time: 1819.2 * Chromosome 13: Score - 579.6   Time: 1182.8 * Chromosome 14: Score - 554.4   Time: 1687.0 * Chromosome 15: Score - 550.2   Time: 1868.6 * Chromosome 16: Score - 546.0   Time: 673.0 * Chromosome 17: Score - 541.8   Time: 1546.8 * Chromosome 18: Score - 533.4   Time: 1737.6 * Chromosome 19: Score - 533.4   Time: 3939.2 * Chromosome 20: Score - 525.0   Time: 1081.2 * Chromosome 21: Score - 520.8   Time: 676.4 * Chromosome 22: Score - 520.8   Time: 1057.4 * Chromosome 23: Score - 520.8   Time: 4066.8 * Chromosome 24: Score - 516.6   Time: 1401.2 * Chromosome 25: Score - 516.6   Time: 1876.2 * Chromosome 26: Score - 512.4   Time: 2762.8 * Chromosome 27: Score - 508.2   Time: 687.6 * Chromosome 28: Score - 504.0   Time: 664.0 * Chromosome 29: Score - 504.0   Time: 703.2 * Chromosome 30: Score - 487.2   Time: 662.2 * Chromosome 31: Score - 483.0   Time: 669.2 * Chromosome 32: Score - 478.8   Time: 605.4 * Chromosome 33: Score - 478.8   Time: 643.6 * Chromosome 34: Score - 478.8   Time: 647.8 * Chromosome 35: Score - 478.8   Time: 659.0 * Chromosome 36: Score - 466.2   Time: 593.2 * Chromosome 37: Score - 457.8   Time: 654.2 * Chromosome 38: Score - 457.8   Time: 678.4 * Chromosome 39: Score - 449.4   Time: 624.8 * Chromosome 40: Score - 445.2   Time: 602.0 * Chromosome 41: Score - 445.2   Time: 625.0 * Chromosome 42: Score - 445.2   Time: 662.0 * Chromosome 43: Score - 441.0   Time: 640.6 * Chromosome 44: Score - 441.0   Time: 646.0 * Chromosome 45: Score - 441.0   Time: 665.8 * Chromosome 46: Score - 436.8   Time: 604.2 * Chromosome 47: Score - 436.8   Time: 653.4 * Chromosome 48: Score - 436.8   Time: 654.6 * Chromosome 49: Score - 428.4   Time: 675.4 * Chromosome 50: Score - 424.2   Time: 606.2 * Chromosome 51: Score - 424.2   Time: 650.2 * Chromosome 52: Score - 420.0   Time: 624.4 * Chromosome 53: Score - 420.0   Time: 632.0 * Chromosome 54: Score - 420.0   Time: 647.0 * Chromosome 55: Score - 420.0   Time: 744.0 * Chromosome 56: Score - 415.8   Time: 598.6 * Chromosome 57: Score - 415.8   Time: 649.2 * Chromosome 58: Score - 411.6   Time: 602.8 * Chromosome 59: Score - 411.6   Time: 615.4 * Chromosome 60: Score - 407.4   Time: 565.0 * Chromosome 61: Score - 407.4   Time: 618.4 * Chromosome 62: Score - 403.2   Time: 580.2 * Chromosome 63: Score - 403.2   Time: 716.8 * Chromosome 64: Score - 399.0   Time: 580.4 * Chromosome 65: Score - 399.0   Time: 609.4 * Chromosome 66: Score - 399.0   Time: 775.6 * Chromosome 67: Score - 394.8   Time: 572.4 * Chromosome 68: Score - 394.8   Time: 637.6 * Chromosome 69: Score - 390.6   Time: 548.4 * Chromosome 70: Score - 390.6   Time: 608.0 * Chromosome 71: Score - 386.4   Time: 569.6 * Chromosome 72: Score - 386.4   Time: 578.4 * Chromosome 73: Score - 382.2   Time: 589.8 * Chromosome 74: Score - 378.0   Time: 580.8 * Chromosome 75: Score - 378.0   Time: 604.4 * Chromosome 76: Score - 373.8   Time: 576.2 * Chromosome 77: Score - 369.6   Time: 575.4 * Chromosome 78: Score - 369.6   Time: 631.6 * Chromosome 79: Score - 365.4   Time: 820.4 * Chromosome 80: Score - 361.2   Time: 502.4 * Chromosome 81: Score - 361.2   Time: 598.6 * Chromosome 82: Score - 357.0   Time: 537.8 * Chromosome 83: Score - 357.0   Time: 547.6 * Chromosome 84: Score - 357.0   Time: 554.6 * Chromosome 85: Score - 357.0   Time: 739.2 * Chromosome 86: Score - 352.8   Time: 509.0 * Chromosome 87: Score - 352.8   Time: 567.8 * Chromosome 88: Score - 352.8   Time: 653.0 * Chromosome 89: Score - 34 ...
# Best Chromosome for Run 10 -> Time Alive: 1810.0    High Score: 680.4
# Chromosome 1: Score - 680.4   Time: 1810.0 * Chromosome 2: Score - 672.0   Time: 1766.8 * Chromosome 3: Score - 667.8   Time: 2301.0 * Chromosome 4: Score - 667.8   Time: 3339.8 * Chromosome 5: Score - 651.0   Time: 1308.8 * Chromosome 6: Score - 651.0   Time: 1763.4 * Chromosome 7: Score - 651.0   Time: 3939.0 * Chromosome 8: Score - 625.8   Time: 1063.8 * Chromosome 9: Score - 617.4   Time: 1468.0 * Chromosome 10: Score - 613.2   Time: 1168.2 * Chromosome 11: Score - 613.2   Time: 2698.8 * Chromosome 12: Score - 596.4   Time: 1018.0 * Chromosome 13: Score - 596.4   Time: 1163.2 * Chromosome 14: Score - 596.4   Time: 5555.2 * Chromosome 15: Score - 588.0   Time: 1819.2 * Chromosome 16: Score - 579.6   Time: 1182.8 * Chromosome 17: Score - 567.0   Time: 1207.6 * Chromosome 18: Score - 550.2   Time: 1868.6 * Chromosome 19: Score - 546.0   Time: 673.0 * Chromosome 20: Score - 541.8   Time: 1546.8 * Chromosome 21: Score - 541.8   Time: 2917.2 * Chromosome 22: Score - 533.4   Time: 1737.6 * Chromosome 23: Score - 525.0   Time: 1081.2 * Chromosome 24: Score - 508.2   Time: 849.4 * Chromosome 25: Score - 487.2   Time: 880.4 * Chromosome 26: Score - 483.0   Time: 673.2 * Chromosome 27: Score - 483.0   Time: 1157.6 * Chromosome 28: Score - 474.6   Time: 1004.2 * Chromosome 29: Score - 470.4   Time: 650.8 * Chromosome 30: Score - 470.4   Time: 654.0 * Chromosome 31: Score - 457.8   Time: 643.8 * Chromosome 32: Score - 457.8   Time: 653.6 * Chromosome 33: Score - 457.8   Time: 658.0 * Chromosome 34: Score - 457.8   Time: 854.6 * Chromosome 35: Score - 449.4   Time: 605.8 * Chromosome 36: Score - 449.4   Time: 611.8 * Chromosome 37: Score - 449.4   Time: 635.2 * Chromosome 38: Score - 449.4   Time: 649.6 * Chromosome 39: Score - 445.2   Time: 625.4 * Chromosome 40: Score - 445.2   Time: 627.6 * Chromosome 41: Score - 445.2   Time: 737.6 * Chromosome 42: Score - 441.0   Time: 591.2 * Chromosome 43: Score - 441.0   Time: 638.4 * Chromosome 44: Score - 441.0   Time: 693.4 * Chromosome 45: Score - 441.0   Time: 1830.0 * Chromosome 46: Score - 436.8   Time: 631.8 * Chromosome 47: Score - 432.6   Time: 598.6 * Chromosome 48: Score - 432.6   Time: 640.6 * Chromosome 49: Score - 432.6   Time: 641.6 * Chromosome 50: Score - 432.6   Time: 804.0 * Chromosome 51: Score - 428.4   Time: 566.6 * Chromosome 52: Score - 428.4   Time: 608.4 * Chromosome 53: Score - 428.4   Time: 612.6 * Chromosome 54: Score - 428.4   Time: 617.0 * Chromosome 55: Score - 424.2   Time: 641.6 * Chromosome 56: Score - 420.0   Time: 652.0 * Chromosome 57: Score - 420.0   Time: 765.6 * Chromosome 58: Score - 415.8   Time: 563.6 * Chromosome 59: Score - 415.8   Time: 593.0 * Chromosome 60: Score - 415.8   Time: 593.4 * Chromosome 61: Score - 411.6   Time: 823.0 * Chromosome 62: Score - 407.4   Time: 583.6 * Chromosome 63: Score - 407.4   Time: 589.0 * Chromosome 64: Score - 407.4   Time: 606.2 * Chromosome 65: Score - 399.0   Time: 580.4 * Chromosome 66: Score - 399.0   Time: 587.0 * Chromosome 67: Score - 394.8   Time: 567.6 * Chromosome 68: Score - 394.8   Time: 588.8 * Chromosome 69: Score - 390.6   Time: 558.2 * Chromosome 70: Score - 390.6   Time: 573.8 * Chromosome 71: Score - 390.6   Time: 583.0 * Chromosome 72: Score - 390.6   Time: 592.4 * Chromosome 73: Score - 386.4   Time: 495.2 * Chromosome 74: Score - 382.2   Time: 571.8 * Chromosome 75: Score - 382.2   Time: 611.8 * Chromosome 76: Score - 378.0   Time: 553.6 * Chromosome 77: Score - 369.6   Time: 526.2 * Chromosome 78: Score - 369.6   Time: 526.2 * Chromosome 79: Score - 369.6   Time: 535.2 * Chromosome 80: Score - 365.4   Time: 626.8 * Chromosome 81: Score - 361.2   Time: 548.4 * Chromosome 82: Score - 361.2   Time: 648.4 * Chromosome 83: Score - 357.0   Time: 509.0 * Chromosome 84: Score - 357.0   Time: 532.2 * Chromosome 85: Score - 352.8   Time: 570.8 * Chromosome 86: Score - 352.8   Time: 678.4 * Chromosome 87: Score - 340.2   Time: 577.2 * Chromosome 88: Score - 336.0   Time: 511.2 * Chromosome 89: Score - 3 ...
# Best Chromosome for Run 11 -> Time Alive: 1810.0    High Score: 680.4
# ...
# Best Chromosome for Run 97 -> Time Alive: 1563.6    High Score: 722.4
# Chromosome 1: Score - 722.4   Time: 1563.6 * Chromosome 2: Score - 705.6   Time: 1428.0 * Chromosome 3: Score - 705.6   Time: 1467.4 * Chromosome 4: Score - 701.4   Time: 1523.8 * Chromosome 5: Score - 701.4   Time: 1676.4 * Chromosome 6: Score - 697.2   Time: 1456.2 * Chromosome 7: Score - 693.0   Time: 1418.6 * Chromosome 8: Score - 693.0   Time: 1670.4 * Chromosome 9: Score - 688.8   Time: 1461.0 * Chromosome 10: Score - 684.6   Time: 1310.6 * Chromosome 11: Score - 684.6   Time: 1438.8 * Chromosome 12: Score - 684.6   Time: 1534.4 * Chromosome 13: Score - 684.6   Time: 1643.0 * Chromosome 14: Score - 680.4   Time: 1323.2 * Chromosome 15: Score - 676.2   Time: 1379.2 * Chromosome 16: Score - 667.8   Time: 1408.6 * Chromosome 17: Score - 667.8   Time: 1411.8 * Chromosome 18: Score - 667.8   Time: 1832.2 * Chromosome 19: Score - 663.6   Time: 1644.2 * Chromosome 20: Score - 659.4   Time: 1394.6 * Chromosome 21: Score - 659.4   Time: 1621.4 * Chromosome 22: Score - 655.2   Time: 1326.2 * Chromosome 23: Score - 655.2   Time: 1349.2 * Chromosome 24: Score - 646.8   Time: 1349.0 * Chromosome 25: Score - 646.8   Time: 1541.4 * Chromosome 26: Score - 642.6   Time: 1305.6 * Chromosome 27: Score - 642.6   Time: 2354.4 * Chromosome 28: Score - 625.8   Time: 1911.8 * Chromosome 29: Score - 625.8   Time: 2104.4 * Chromosome 30: Score - 617.4   Time: 1702.0 * Chromosome 31: Score - 604.8   Time: 2673.2 * Chromosome 32: Score - 596.4   Time: 1368.6 * Chromosome 33: Score - 562.8   Time: 2608.8 * Chromosome 34: Score - 504.0   Time: 1305.0 * Chromosome 35: Score - 487.2   Time: 909.4 * Chromosome 36: Score - 483.0   Time: 618.6 * Chromosome 37: Score - 483.0   Time: 624.8 * Chromosome 38: Score - 483.0   Time: 659.6 * Chromosome 39: Score - 474.6   Time: 655.6 * Chromosome 40: Score - 474.6   Time: 669.8 * Chromosome 41: Score - 470.4   Time: 647.8 * Chromosome 42: Score - 462.0   Time: 653.8 * Chromosome 43: Score - 462.0   Time: 981.2 * Chromosome 44: Score - 457.8   Time: 601.6 * Chromosome 45: Score - 457.8   Time: 611.4 * Chromosome 46: Score - 457.8   Time: 618.8 * Chromosome 47: Score - 457.8   Time: 673.6 * Chromosome 48: Score - 449.4   Time: 605.8 * Chromosome 49: Score - 449.4   Time: 670.0 * Chromosome 50: Score - 449.4   Time: 686.0 * Chromosome 51: Score - 449.4   Time: 916.2 * Chromosome 52: Score - 445.2   Time: 596.0 * Chromosome 53: Score - 445.2   Time: 627.6 * Chromosome 54: Score - 445.2   Time: 628.2 * Chromosome 55: Score - 441.0   Time: 598.8 * Chromosome 56: Score - 441.0   Time: 602.6 * Chromosome 57: Score - 441.0   Time: 640.2 * Chromosome 58: Score - 441.0   Time: 643.4 * Chromosome 59: Score - 436.8   Time: 625.4 * Chromosome 60: Score - 432.6   Time: 604.8 * Chromosome 61: Score - 432.6   Time: 609.0 * Chromosome 62: Score - 432.6   Time: 670.4 * Chromosome 63: Score - 424.2   Time: 601.6 * Chromosome 64: Score - 424.2   Time: 620.2 * Chromosome 65: Score - 420.0   Time: 622.4 * Chromosome 66: Score - 415.8   Time: 643.2 * Chromosome 67: Score - 411.6   Time: 578.6 * Chromosome 68: Score - 411.6   Time: 596.2 * Chromosome 69: Score - 411.6   Time: 655.8 * Chromosome 70: Score - 407.4   Time: 587.8 * Chromosome 71: Score - 407.4   Time: 599.8 * Chromosome 72: Score - 407.4   Time: 4508.0 * Chromosome 73: Score - 403.2   Time: 566.8 * Chromosome 74: Score - 399.0   Time: 608.8 * Chromosome 75: Score - 394.8   Time: 587.4 * Chromosome 76: Score - 394.8   Time: 599.0 * Chromosome 77: Score - 390.6   Time: 523.6 * Chromosome 78: Score - 390.6   Time: 582.2 * Chromosome 79: Score - 390.6   Time: 630.2 * Chromosome 80: Score - 390.6   Time: 631.8 * Chromosome 81: Score - 382.2   Time: 590.2 * Chromosome 82: Score - 378.0   Time: 564.2 * Chromosome 83: Score - 378.0   Time: 580.4 * Chromosome 84: Score - 378.0   Time: 638.0 * Chromosome 85: Score - 373.8   Time: 525.2 * Chromosome 86: Score - 373.8   Time: 551.2 * Chromosome 87: Score - 373.8   Time: 556.2 * Chromosome 88: Score - 373.8   Time: 563.8 * Chromosome 89: ...
# Best Chromosome for Run 98 -> Time Alive: 1563.6    High Score: 722.4
# Chromosome 1: Score - 722.4   Time: 1563.6 * Chromosome 2: Score - 705.6   Time: 1428.0 * Chromosome 3: Score - 705.6   Time: 1467.4 * Chromosome 4: Score - 701.4   Time: 1492.0 * Chromosome 5: Score - 701.4   Time: 1523.8 * Chromosome 6: Score - 701.4   Time: 1676.4 * Chromosome 7: Score - 697.2   Time: 1456.2 * Chromosome 8: Score - 693.0   Time: 1418.6 * Chromosome 9: Score - 693.0   Time: 1670.4 * Chromosome 10: Score - 688.8   Time: 1459.4 * Chromosome 11: Score - 688.8   Time: 1461.0 * Chromosome 12: Score - 684.6   Time: 1438.8 * Chromosome 13: Score - 684.6   Time: 1534.4 * Chromosome 14: Score - 684.6   Time: 1643.0 * Chromosome 15: Score - 676.2   Time: 1379.2 * Chromosome 16: Score - 676.2   Time: 1470.4 * Chromosome 17: Score - 672.0   Time: 1411.4 * Chromosome 18: Score - 667.8   Time: 1408.6 * Chromosome 19: Score - 667.8   Time: 1832.2 * Chromosome 20: Score - 663.6   Time: 1644.2 * Chromosome 21: Score - 659.4   Time: 1394.6 * Chromosome 22: Score - 625.8   Time: 1532.6 * Chromosome 23: Score - 625.8   Time: 1559.6 * Chromosome 24: Score - 613.2   Time: 1362.4 * Chromosome 25: Score - 609.0   Time: 1807.4 * Chromosome 26: Score - 588.0   Time: 1265.2 * Chromosome 27: Score - 562.8   Time: 1376.0 * Chromosome 28: Score - 541.8   Time: 2166.4 * Chromosome 29: Score - 520.8   Time: 1762.0 * Chromosome 30: Score - 508.2   Time: 660.6 * Chromosome 31: Score - 508.2   Time: 1829.6 * Chromosome 32: Score - 499.8   Time: 936.4 * Chromosome 33: Score - 491.4   Time: 660.6 * Chromosome 34: Score - 491.4   Time: 664.0 * Chromosome 35: Score - 478.8   Time: 643.8 * Chromosome 36: Score - 478.8   Time: 690.0 * Chromosome 37: Score - 474.6   Time: 1207.2 * Chromosome 38: Score - 470.4   Time: 1149.2 * Chromosome 39: Score - 466.2   Time: 666.8 * Chromosome 40: Score - 466.2   Time: 668.6 * Chromosome 41: Score - 462.0   Time: 652.8 * Chromosome 42: Score - 457.8   Time: 676.2 * Chromosome 43: Score - 457.8   Time: 851.0 * Chromosome 44: Score - 453.6   Time: 668.6 * Chromosome 45: Score - 453.6   Time: 2410.0 * Chromosome 46: Score - 445.2   Time: 622.2 * Chromosome 47: Score - 445.2   Time: 645.0 * Chromosome 48: Score - 441.0   Time: 573.0 * Chromosome 49: Score - 436.8   Time: 640.6 * Chromosome 50: Score - 432.6   Time: 644.6 * Chromosome 51: Score - 432.6   Time: 646.2 * Chromosome 52: Score - 428.4   Time: 582.2 * Chromosome 53: Score - 428.4   Time: 590.2 * Chromosome 54: Score - 428.4   Time: 628.2 * Chromosome 55: Score - 424.2   Time: 564.2 * Chromosome 56: Score - 424.2   Time: 618.2 * Chromosome 57: Score - 424.2   Time: 871.8 * Chromosome 58: Score - 420.0   Time: 589.4 * Chromosome 59: Score - 420.0   Time: 609.0 * Chromosome 60: Score - 420.0   Time: 634.4 * Chromosome 61: Score - 420.0   Time: 636.4 * Chromosome 62: Score - 420.0   Time: 644.0 * Chromosome 63: Score - 415.8   Time: 606.2 * Chromosome 64: Score - 415.8   Time: 613.4 * Chromosome 65: Score - 415.8   Time: 654.0 * Chromosome 66: Score - 415.8   Time: 909.6 * Chromosome 67: Score - 411.6   Time: 593.6 * Chromosome 68: Score - 407.4   Time: 649.0 * Chromosome 69: Score - 403.2   Time: 575.4 * Chromosome 70: Score - 403.2   Time: 593.4 * Chromosome 71: Score - 403.2   Time: 606.4 * Chromosome 72: Score - 403.2   Time: 637.4 * Chromosome 73: Score - 403.2   Time: 2985.0 * Chromosome 74: Score - 394.8   Time: 566.8 * Chromosome 75: Score - 394.8   Time: 614.8 * Chromosome 76: Score - 386.4   Time: 555.2 * Chromosome 77: Score - 386.4   Time: 595.8 * Chromosome 78: Score - 378.0   Time: 588.8 * Chromosome 79: Score - 373.8   Time: 571.6 * Chromosome 80: Score - 373.8   Time: 609.0 * Chromosome 81: Score - 369.6   Time: 553.8 * Chromosome 82: Score - 365.4   Time: 510.2 * Chromosome 83: Score - 361.2   Time: 579.0 * Chromosome 84: Score - 361.2   Time: 589.6 * Chromosome 85: Score - 361.2   Time: 667.6 * Chromosome 86: Score - 357.0   Time: 596.2 * Chromosome 87: Score - 357.0   Time: 618.0 * Chromosome 88: Score - 352.8   Time: 580.4 * Chromosome 89:  ...
# Best Chromosome for Run 99 -> Time Alive: 1563.6    High Score: 722.4
# Chromosome 1: Score - 722.4   Time: 1563.6 * Chromosome 2: Score - 705.6   Time: 1428.0 * Chromosome 3: Score - 705.6   Time: 1467.4 * Chromosome 4: Score - 701.4   Time: 1492.0 * Chromosome 5: Score - 701.4   Time: 1523.8 * Chromosome 6: Score - 701.4   Time: 1676.4 * Chromosome 7: Score - 697.2   Time: 1456.2 * Chromosome 8: Score - 693.0   Time: 1670.4 * Chromosome 9: Score - 693.0   Time: 1701.8 * Chromosome 10: Score - 688.8   Time: 1459.4 * Chromosome 11: Score - 688.8   Time: 1461.0 * Chromosome 12: Score - 688.8   Time: 1589.0 * Chromosome 13: Score - 684.6   Time: 1438.8 * Chromosome 14: Score - 684.6   Time: 1643.0 * Chromosome 15: Score - 676.2   Time: 1379.2 * Chromosome 16: Score - 676.2   Time: 1470.4 * Chromosome 17: Score - 672.0   Time: 1411.4 * Chromosome 18: Score - 667.8   Time: 1832.2 * Chromosome 19: Score - 667.8   Time: 2156.4 * Chromosome 20: Score - 663.6   Time: 1178.2 * Chromosome 21: Score - 663.6   Time: 1305.4 * Chromosome 22: Score - 663.6   Time: 1494.4 * Chromosome 23: Score - 663.6   Time: 1644.2 * Chromosome 24: Score - 663.6   Time: 1891.0 * Chromosome 25: Score - 659.4   Time: 1470.0 * Chromosome 26: Score - 651.0   Time: 1397.8 * Chromosome 27: Score - 646.8   Time: 1256.8 * Chromosome 28: Score - 646.8   Time: 1855.0 * Chromosome 29: Score - 638.4   Time: 1496.8 * Chromosome 30: Score - 638.4   Time: 1553.4 * Chromosome 31: Score - 634.2   Time: 1666.8 * Chromosome 32: Score - 634.2   Time: 1810.6 * Chromosome 33: Score - 617.4   Time: 1635.2 * Chromosome 34: Score - 579.6   Time: 1237.0 * Chromosome 35: Score - 579.6   Time: 1885.4 * Chromosome 36: Score - 550.2   Time: 1681.0 * Chromosome 37: Score - 537.6   Time: 1015.8 * Chromosome 38: Score - 499.8   Time: 1119.4 * Chromosome 39: Score - 495.6   Time: 657.4 * Chromosome 40: Score - 495.6   Time: 2306.6 * Chromosome 41: Score - 487.2   Time: 2892.6 * Chromosome 42: Score - 478.8   Time: 640.4 * Chromosome 43: Score - 466.2   Time: 600.4 * Chromosome 44: Score - 466.2   Time: 649.4 * Chromosome 45: Score - 457.8   Time: 651.0 * Chromosome 46: Score - 457.8   Time: 1942.6 * Chromosome 47: Score - 449.4   Time: 615.8 * Chromosome 48: Score - 449.4   Time: 798.2 * Chromosome 49: Score - 441.0   Time: 646.0 * Chromosome 50: Score - 441.0   Time: 656.4 * Chromosome 51: Score - 441.0   Time: 792.0 * Chromosome 52: Score - 436.8   Time: 614.6 * Chromosome 53: Score - 436.8   Time: 622.2 * Chromosome 54: Score - 432.6   Time: 667.8 * Chromosome 55: Score - 428.4   Time: 575.8 * Chromosome 56: Score - 428.4   Time: 597.6 * Chromosome 57: Score - 428.4   Time: 606.0 * Chromosome 58: Score - 428.4   Time: 634.8 * Chromosome 59: Score - 424.2   Time: 531.4 * Chromosome 60: Score - 424.2   Time: 551.6 * Chromosome 61: Score - 420.0   Time: 593.6 * Chromosome 62: Score - 415.8   Time: 612.2 * Chromosome 63: Score - 415.8   Time: 639.6 * Chromosome 64: Score - 415.8   Time: 2818.4 * Chromosome 65: Score - 407.4   Time: 563.8 * Chromosome 66: Score - 403.2   Time: 574.0 * Chromosome 67: Score - 403.2   Time: 596.6 * Chromosome 68: Score - 403.2   Time: 599.0 * Chromosome 69: Score - 403.2   Time: 643.2 * Chromosome 70: Score - 399.0   Time: 531.2 * Chromosome 71: Score - 399.0   Time: 630.0 * Chromosome 72: Score - 386.4   Time: 533.8 * Chromosome 73: Score - 386.4   Time: 718.8 * Chromosome 74: Score - 382.2   Time: 551.6 * Chromosome 75: Score - 382.2   Time: 606.0 * Chromosome 76: Score - 382.2   Time: 652.0 * Chromosome 77: Score - 373.8   Time: 585.0 * Chromosome 78: Score - 373.8   Time: 612.6 * Chromosome 79: Score - 369.6   Time: 531.0 * Chromosome 80: Score - 369.6   Time: 570.0 * Chromosome 81: Score - 369.6   Time: 600.8 * Chromosome 82: Score - 365.4   Time: 542.4 * Chromosome 83: Score - 365.4   Time: 592.2 * Chromosome 84: Score - 361.2   Time: 550.0 * Chromosome 85: Score - 361.2   Time: 574.2 * Chromosome 86: Score - 361.2   Time: 578.4 * Chromosome 87: Score - 361.2   Time: 589.4 * Chromosome 88: Score - 357.0   Time: 552.6 * Chromos ...
# Best Chromosome for Run 100 -> Time Alive: 1563.6    High Score: 722.4
# Best Chromosome -> Time Alive: 1563.6    High Score: 722.4

# %%
"""
This displays the game to evaluate our best chromosome.
"""
test_env = gym.make('ALE/Assault-v5', render_mode="human", full_action_space=False)

file = open("cnn_s722.pickle",'rb')
best_chromo = pickle.load(file)

done = False
obs = test_env.reset()
frame1 = obs_to_tensor(obs)
frame2 = deepcopy(frame1)
frame3 = deepcopy(frame1)
frame4 = deepcopy(frame1)

time_alive = 0
reward_sum = 0

while(done == False):

    stacked_obs = torch.unsqueeze(torch.stack([frame1, frame2, frame3, frame4]), 0)

    action = best_chromo.nn(stacked_obs)
    
    obs, reward, done, info = test_env.step(action)

    frame1, frame2, frame3, frame4 = restack(frame2, frame3, frame4, obs_to_tensor(obs))

    reward_sum = reward_sum + reward
    time_alive = time_alive + 1

file.close()
print(f"Longest Alive: {time_alive}    High Score: {reward_sum}")
# Out:
# Longest Alive: 1489    High Score: 714.0
