# %%
"""
Dependencies: gym, ale-py

pip install gym[atari,accept-rom-license]

"""

import gym
import random
import numpy as np

from copy import copy, deepcopy

from functools import cmp_to_key

import torch
from torch import nn
from torchvision import transforms

import pickle
import time
# Out:
# c:\Users\icarus\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\wrappers\monitoring\video_recorder.py:9: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   import distutils.spawn

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform_obs = transforms.Compose([
    transforms.ToTensor(),
    transforms.Grayscale(),
    transforms.Resize(size=(84,84)),
    transforms.Normalize([0.5], [0.5]),

])

def obs_to_tensor(obs):
   return torch.unsqueeze(torch.flatten(transform_obs(np.array(obs))), 0).to(device)


# Initialize weights to something random.
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0.01)
  
class Agent_MLP(nn.Module):
    def __init__(self):
      super().__init__() 
      self.model = nn.Sequential(
        nn.Linear(7056, 1024),
        nn.ReLU(),     
        nn.Linear(1024, 128),
        nn.ReLU(),     
        nn.Linear(128, 7),
        nn.ReLU(),     
        nn.Softmax()
      )

      # Manually initialize random weights
      self.model.apply(init_weights)
    
    def forward(self, x):
      with torch.no_grad():
        arr = self.model(x)
        arr = arr.cpu().detach().numpy()
        action = np.argmax(arr)
        return action
    
    def getWeights(self):
      weight_dict = {}
      weight_dict["l1"] = self.model[0].weight.cpu().detach().numpy()
      weight_dict["l2"] = self.model[2].weight.cpu().detach().numpy()
      weight_dict["l3"] = self.model[4].weight.cpu().detach().numpy()

      return weight_dict
    
    def setWeights(self, weight_dict):

      self.model[0].weight = nn.Parameter(torch.from_numpy(weight_dict["l1"]).float().to(device), requires_grad = False)
      self.model[2].weight = nn.Parameter(torch.from_numpy(weight_dict["l2"]).float().to(device), requires_grad = False)
      self.model[4].weight = nn.Parameter(torch.from_numpy(weight_dict["l3"]).float().to(device), requires_grad = False)

# %%
"""
Action space is of size 7:

0 NOOP
1 FIRE
2 UP
3 RIGHT
4 LEFT
5 RIGHTFIRE
6 LEFTFIRE
"""

"""
A class for each chromosome.
"""
class Chromosome:

    """
    This is used to initialize a chromosome

    args is used since Python doesn't support multiple constructors. (self, env) initializes a chromosome with a random
    action sequence and is used during population initialization.

    (self, actions, env) is used during crossover to generate new chromosomes given a crossed action buffer.
    """
    def __init__(self, *args):

        if len(args) > 1:
            self.nn = Agent_MLP()
            self.nn.to(device)
            self.nn.eval()
            self.nn.setWeights(args[0])
            self.env = args[1]
            self.reward_sum = 0
            self.time_alive = 0

            return

        # Stores actions taken, rewards obtained, total reward for the run, and the number of frames that the agent has been alive for.

        self.nn = Agent_MLP()
        self.nn.to(device)
        self.nn.eval()

        self.reward_sum = 0
        self.time_alive = 0

        # Store the provided env as a class variable.
        self.env = args[0]

        obs = self.env.reset()
        done = False

        while(done == False):

            action = self.nn(obs_to_tensor(obs))

            obs, reward, done, _ = self.env.step(action)

            self.time_alive = self.time_alive + 1
            self.reward_sum = self.reward_sum + reward

    """
    This reruns the environment and performs a new run with the updated action buffer to generate new stats.
    """
    def update(self, num):

        # Stores updated actions and rewards taken.
        self.nn.eval()

        times = []
        scores = []

        for i in range(0, num):
            curReward = 0
            curTime = 0

            obs = self.env.reset()

            done = False

            while(done == False):

                action = self.nn(obs_to_tensor(obs))

                obs, reward, done, info = self.env.step(action)

                curTime = curTime + 1
                curReward = curReward + reward

            times.append(curTime)
            scores.append(curReward)

        self.reward_sum = np.mean(np.array(scores))
        self.time_alive = np.mean(np.array(times))

    """
    Since the environment has a certain level of randomness, this function reruns it without saving results
    except the aggregate reward and time alive. Used to gauge how accurate a score is during fitness.
    """
    def simulate(self):

        # This is needed in case we manage to survive for more frames than the action buffer has actions, in which case we do random ones.
        counter = 0

        new_reward_sum = 0
        new_time_alive = 0

        obs = self.env.reset()

        done = False

        while(done == False):

            # Determine if action is from supplied buffer or random.
            counter = counter + 1

            action = self.nn(obs_to_tensor(obs))

            obs, reward, done, _ = self.env.step(action)

            new_time_alive = self.time_alive + 1
            new_reward_sum = self.reward_sum + reward

        return new_reward_sum, new_time_alive

    """
    This mutates a chromosome's genes (NN weights) based on a supplied probability. If the mutation occurs, the action is replaced with a random one.
    """
    def mutate(self, mutation_rate, mutation_factor=0.01):
        weight_dict = self.nn.getWeights()
        for key, val in weight_dict.items():
            std = np.std(val)
            for i in range(0, len(val)):
                for j in range(0, len(val[i])):
                    if random.random() <= mutation_rate:
                        curWeight = val[i][j]
                        mutation_amount = np.random.normal(0, std)
                        val[i][j] = curWeight + mutation_factor * mutation_amount

            weight_dict[key] = val

        self.nn.setWeights(weight_dict)

# %%
"""
GA and helper methods
"""

#Comparator for a Chromosome list
def chromosome_comparator(a, b):
    if a.reward_sum > b.reward_sum:
        return 1
    elif a.reward_sum == b.reward_sum:
        if a.time_alive < b.time_alive:
            return -1
        else:
            return 1
    else:
        return -1

# Feed this to sorting function
compare_key = cmp_to_key(chromosome_comparator)

# Generates initial population
def create_initial_population(number, env):
    population = []

    for i in range(0, number):
        population.append(Chromosome(env))

    return population

def list_population(population):
    outString = ""

    for i, chrom in enumerate(population):
        outString = outString + f"Chromosome {i+1}: Score - {chrom.reward_sum}   Time: {chrom.time_alive} * "

    print(outString)


"""
Applies a fitness function and then ranks the population in descending order of best to worst.

In this case, the primary marker of fitness is the high score. Assuming a tie, then secondary criterion is how long each agent has been alive.

Also returns the best chromosome found.
"""
def selection(population):

    # The first stage is the fitness function.
    optimal_index = 0
    longest_alive = 1000000
    max_score = 0
    n = len(population)
    scores = []

    for i, chrom in enumerate(population):

        chrom.update(5)

        if chrom.reward_sum > max_score:
            best = True
        elif (chrom.reward_sum == max_score) and longest_alive < chrom.time_alive:
            best = True
        else:
            best = False

        if best:
            longest_alive = chrom.time_alive
            max_score = chrom.reward_sum
            optimal_index = i

    selected_population = []

    # Select best chromosome.
    best_chromosome = deepcopy(population[optimal_index])
    population.sort(key=compare_key, reverse=True)

    for l in range(0, int(len(population) / 10)):  
        selected_population.append(population.pop(l))

    scores = []
    for l in range(0, len(population)):
        scores.append(population[l].reward_sum)

    scores = [1 if x <=0 else x for x in scores]

    scores = np.array(scores)

    # Select chromosomes probabilistically.
    for k in range(0, int(len(population)/2) - int(len(selected_population) / 2)):
        probs = scores / np.sum(scores)

        ind = np.random.choice(np.arange(0, len(population)), size=None, replace=True, p=probs)
        selected_population.append(population.pop(ind))

        scores = np.delete(scores, ind)
    
    selected_population.sort(key=compare_key, reverse=True)
    list_population(selected_population)

    return selected_population, best_chromosome

"""
Performs crossover on a population and returns the new population.

Crossover is done by combining the weights of the parental nns.
"""
def crossover(population):
    crossed_population = []
    father = population[0]

    for i in range(0, len(population) * 2):

        if i == 0:
            crossed_population.append(father)
            continue
            
        else:
            father_index = random.randint(0, len(population)-1)
            mother_index = None
            got_index = False

            while(not got_index):
                mother_index = random.randint(0, len(population)-1)
                if mother_index != father_index:
                    got_index = True
            
            father = population[father_index]
            mother = population[mother_index]

        motherWeights = mother.nn.getWeights()
        fatherWeights = father.nn.getWeights()

        newWeights = deepcopy(fatherWeights)

        for key, val in newWeights.items():
            for k in range(0, len(val)):

                crossover_point = random.randint(0, len(val[k]))

                for l in range(0, len(val[k])):
                    if l >= crossover_point:
                        val[k][l] = motherWeights[key][k][l]

            newWeights[key] = val

        crossed_population.append(Chromosome(newWeights, father.env))

    return crossed_population

"""
Mutate the population. Rate represents chance of mutation.
"""
def mutate_population(population, rate=0.001):
    for i, chrom in enumerate(population):

        # Don't mutate the best chromosome retained from previous population
        if i == 0:
            continue 
        
        else:
            chrom.mutate(rate)

"""
Rerun the environment for all chromosomes and produce updated runs.
"""
def update_population(population):
    for i, chrom in enumerate(population): 
         
         # Don't update best chromosome, as there is no need
         if i == 0:
            continue 
             
         chrom.update()

# %%
"""
GA loop
"""

env = gym.make('ALE/Assault-v5', full_action_space=False)

n_iter = 100
population_size = 20
mutation_rate = 0.002

best_alive = 0
best_score = 0
best_chromo = None

population = create_initial_population(population_size, env)

start_time = time.time()

for i in range(0, n_iter):

    # Run the fitness function and determine if the best chromosome is better than the best one we've stored for all runs.
    selected_population, best_chromo_candidate = selection(population)
    longest_alive = best_chromo_candidate.time_alive
    max_score = best_chromo_candidate.reward_sum

    if best_chromo_candidate.reward_sum > best_score:
            best = True
    elif (best_chromo_candidate.reward_sum == best_score) and best_chromo_candidate.time_alive > best_alive:
            best = True
    else:
        if i == 0:
                best = True
        else:
                best = False

    if best:
           best_chromo = deepcopy(best_chromo_candidate)
           best_alive = best_chromo_candidate.time_alive
           best_score = best_chromo_candidate.reward_sum

           file = open(f'best_chromo_{start_time}.pickle', 'wb')

           # dump information to file
           pickle.dump(best_chromo, file)

           # close the file
           file.close()
           

    # Print stats.
    print(f"Best Chromosome for Run {i + 1} -> Longest Alive: {longest_alive}    High Score: {max_score}")

    # Cross, Mutate, Update, and prepare the new population for the next run.
    crossed_population = crossover(selected_population)
    mutate_population(crossed_population, mutation_rate)

    population = crossed_population

print(f"Best Chromosome -> Longest Alive: {best_alive}    High Score: {best_score}")
# Out:
# Chromosome 1: Score - 554.4   Time: 2323.8 * Chromosome 2: Score - 46.2   Time: 338.4 * Chromosome 3: Score - 21.0   Time: 347.2 * Chromosome 4: Score - 0.0   Time: 4027.6 * Chromosome 5: Score - 0.0   Time: 3656.4 * Chromosome 6: Score - 0.0   Time: 3406.8 * Chromosome 7: Score - 0.0   Time: 2888.4 * Chromosome 8: Score - 0.0   Time: 1742.8 * Chromosome 9: Score - 0.0   Time: 357.6 * Chromosome 10: Score - 0.0   Time: 336.2 *
# Best Chromosome for Run 1 -> Longest Alive: 2323.8    High Score: 554.4
# Chromosome 1: Score - 525.0   Time: 2245.4 * Chromosome 2: Score - 432.6   Time: 605.8 * Chromosome 3: Score - 415.8   Time: 611.4 * Chromosome 4: Score - 407.4   Time: 593.4 * Chromosome 5: Score - 399.0   Time: 651.0 * Chromosome 6: Score - 0.0   Time: 3438.8 * Chromosome 7: Score - 0.0   Time: 3061.2 * Chromosome 8: Score - 0.0   Time: 2894.8 * Chromosome 9: Score - 0.0   Time: 519.8 * Chromosome 10: Score - 0.0   Time: 300.8 *
# Best Chromosome for Run 2 -> Longest Alive: 2245.4    High Score: 525.0
# Chromosome 1: Score - 583.8   Time: 2417.4 * Chromosome 2: Score - 462.0   Time: 646.2 * Chromosome 3: Score - 432.6   Time: 597.8 * Chromosome 4: Score - 403.2   Time: 582.0 * Chromosome 5: Score - 373.8   Time: 558.0 * Chromosome 6: Score - 222.6   Time: 1774.4 * Chromosome 7: Score - 4.2   Time: 280.8 * Chromosome 8: Score - 0.0   Time: 3176.4 * Chromosome 9: Score - 0.0   Time: 661.2 * Chromosome 10: Score - 0.0   Time: 381.2 *
# Best Chromosome for Run 3 -> Longest Alive: 2417.4    High Score: 583.8
# Chromosome 1: Score - 504.0   Time: 679.4 * Chromosome 2: Score - 499.8   Time: 677.2 * Chromosome 3: Score - 478.8   Time: 1822.8 * Chromosome 4: Score - 474.6   Time: 675.4 * Chromosome 5: Score - 428.4   Time: 547.4 * Chromosome 6: Score - 407.4   Time: 547.0 * Chromosome 7: Score - 378.0   Time: 712.4 * Chromosome 8: Score - 365.4   Time: 918.8 * Chromosome 9: Score - 344.4   Time: 528.2 * Chromosome 10: Score - 256.2   Time: 505.8 *
# Best Chromosome for Run 4 -> Longest Alive: 679.4    High Score: 504.0
# Chromosome 1: Score - 621.6   Time: 1668.0 * Chromosome 2: Score - 457.8   Time: 634.6 * Chromosome 3: Score - 445.2   Time: 675.0 * Chromosome 4: Score - 436.8   Time: 686.6 * Chromosome 5: Score - 415.8   Time: 626.2 * Chromosome 6: Score - 394.8   Time: 616.4 * Chromosome 7: Score - 394.8   Time: 581.4 * Chromosome 8: Score - 352.8   Time: 524.0 * Chromosome 9: Score - 331.8   Time: 495.2 * Chromosome 10: Score - 327.6   Time: 535.8 *
# Best Chromosome for Run 5 -> Longest Alive: 1668.0    High Score: 621.6
# Chromosome 1: Score - 596.4   Time: 1336.0 * Chromosome 2: Score - 483.0   Time: 633.8 * Chromosome 3: Score - 470.4   Time: 653.6 * Chromosome 4: Score - 445.2   Time: 663.8 * Chromosome 5: Score - 436.8   Time: 628.6 * Chromosome 6: Score - 424.2   Time: 638.4 * Chromosome 7: Score - 420.0   Time: 601.6 * Chromosome 8: Score - 415.8   Time: 622.2 * Chromosome 9: Score - 407.4   Time: 594.2 * Chromosome 10: Score - 373.8   Time: 596.8 *
# Best Chromosome for Run 6 -> Longest Alive: 1336.0    High Score: 596.4
# Chromosome 1: Score - 609.0   Time: 1658.8 * Chromosome 2: Score - 441.0   Time: 713.2 * Chromosome 3: Score - 432.6   Time: 620.6 * Chromosome 4: Score - 428.4   Time: 639.8 * Chromosome 5: Score - 415.8   Time: 598.6 * Chromosome 6: Score - 411.6   Time: 582.4 * Chromosome 7: Score - 369.6   Time: 567.0 * Chromosome 8: Score - 352.8   Time: 547.4 * Chromosome 9: Score - 340.2   Time: 575.4 * Chromosome 10: Score - 226.8   Time: 1717.2 *
# Best Chromosome for Run 7 -> Longest Alive: 1658.8    High Score: 609.0
# Chromosome 1: Score - 617.4   Time: 1559.4 * Chromosome 2: Score - 441.0   Time: 780.8 * Chromosome 3: Score - 432.6   Time: 623.6 * Chromosome 4: Score - 424.2   Time: 602.6 * Chromosome 5: Score - 420.0   Time: 640.8 * Chromosome 6: Score - 411.6   Time: 570.8 * Chromosome 7: Score - 411.6   Time: 561.2 * Chromosome 8: Score - 407.4   Time: 601.0 * Chromosome 9: Score - 382.2   Time: 605.8 * Chromosome 10: Score - 100.8   Time: 476.6 *
# Best Chromosome for Run 8 -> Longest Alive: 1559.4    High Score: 617.4
# Chromosome 1: Score - 634.2   Time: 1759.8 * Chromosome 2: Score - 449.4   Time: 680.0 * Chromosome 3: Score - 424.2   Time: 595.6 * Chromosome 4: Score - 420.0   Time: 604.2 * Chromosome 5: Score - 411.6   Time: 614.8 * Chromosome 6: Score - 407.4   Time: 638.0 * Chromosome 7: Score - 403.2   Time: 619.0 * Chromosome 8: Score - 390.6   Time: 579.0 * Chromosome 9: Score - 386.4   Time: 624.4 * Chromosome 10: Score - 222.6   Time: 878.8 *
# Best Chromosome for Run 9 -> Longest Alive: 1759.8    High Score: 634.2
# Chromosome 1: Score - 684.6   Time: 1694.6 * Chromosome 2: Score - 441.0   Time: 626.8 * Chromosome 3: Score - 428.4   Time: 612.8 * Chromosome 4: Score - 407.4   Time: 577.2 * Chromosome 5: Score - 399.0   Time: 567.4 * Chromosome 6: Score - 394.8   Time: 666.0 * Chromosome 7: Score - 394.8   Time: 655.8 * Chromosome 8: Score - 390.6   Time: 573.2 * Chromosome 9: Score - 386.4   Time: 612.4 * Chromosome 10: Score - 361.2   Time: 529.0 *
# Best Chromosome for Run 10 -> Longest Alive: 1694.6    High Score: 684.6
# Chromosome 1: Score - 617.4   Time: 1744.6 * Chromosome 2: Score - 491.4   Time: 1124.0 * Chromosome 3: Score - 445.2   Time: 644.6 * Chromosome 4: Score - 420.0   Time: 657.2 * Chromosome 5: Score - 407.4   Time: 618.0 * Chromosome 6: Score - 386.4   Time: 590.8 * Chromosome 7: Score - 378.0   Time: 517.6 * Chromosome 8: Score - 365.4   Time: 558.0 * Chromosome 9: Score - 348.6   Time: 3964.2 * Chromosome 10: Score - 340.2   Time: 634.8 *
# Best Chromosome for Run 11 -> Longest Alive: 1744.6    High Score: 617.4
# Chromosome 1: Score - 638.4   Time: 1704.6 * Chromosome 2: Score - 491.4   Time: 671.6 * Chromosome 3: Score - 441.0   Time: 637.8 * Chromosome 4: Score - 415.8   Time: 615.2 * Chromosome 5: Score - 415.8   Time: 592.2 * Chromosome 6: Score - 399.0   Time: 641.4 * Chromosome 7: Score - 399.0   Time: 608.6 * Chromosome 8: Score - 382.2   Time: 593.4 * Chromosome 9: Score - 365.4   Time: 795.6 * Chromosome 10: Score - 340.2   Time: 529.4 *
# Best Chromosome for Run 12 -> Longest Alive: 1704.6    High Score: 638.4
# Chromosome 1: Score - 638.4   Time: 1542.4 * Chromosome 2: Score - 499.8   Time: 702.2 * Chromosome 3: Score - 453.6   Time: 1610.8 * Chromosome 4: Score - 432.6   Time: 590.2 * Chromosome 5: Score - 415.8   Time: 641.2 * Chromosome 6: Score - 415.8   Time: 618.0 * Chromosome 7: Score - 403.2   Time: 609.6 * Chromosome 8: Score - 382.2   Time: 551.4 * Chromosome 9: Score - 369.6   Time: 537.6 * Chromosome 10: Score - 344.4   Time: 512.0 *
# Best Chromosome for Run 13 -> Longest Alive: 1542.4    High Score: 638.4
# Chromosome 1: Score - 621.6   Time: 1747.6 * Chromosome 2: Score - 483.0   Time: 923.0 * Chromosome 3: Score - 483.0   Time: 657.2 * Chromosome 4: Score - 457.8   Time: 665.8 * Chromosome 5: Score - 415.8   Time: 554.6 * Chromosome 6: Score - 407.4   Time: 599.4 * Chromosome 7: Score - 382.2   Time: 587.0 * Chromosome 8: Score - 361.2   Time: 604.0 * Chromosome 9: Score - 357.0   Time: 624.0 * Chromosome 10: Score - 340.2   Time: 537.8 *
# Best Chromosome for Run 14 -> Longest Alive: 1747.6    High Score: 621.6
# Chromosome 1: Score - 588.0   Time: 2118.6 * Chromosome 2: Score - 529.2   Time: 1442.8 * Chromosome 3: Score - 457.8   Time: 605.6 * Chromosome 4: Score - 445.2   Time: 704.2 * Chromosome 5: Score - 407.4   Time: 608.6 * Chromosome 6: Score - 390.6   Time: 579.2 * Chromosome 7: Score - 386.4   Time: 586.8 * Chromosome 8: Score - 348.6   Time: 538.2 * Chromosome 9: Score - 340.2   Time: 547.4 * Chromosome 10: Score - 319.2   Time: 470.6 *
# Best Chromosome for Run 15 -> Longest Alive: 2118.6    High Score: 588.0
# Chromosome 1: Score - 562.8   Time: 2637.2 * Chromosome 2: Score - 445.2   Time: 666.6 * Chromosome 3: Score - 420.0   Time: 673.2 * Chromosome 4: Score - 407.4   Time: 612.4 * Chromosome 5: Score - 403.2   Time: 585.6 * Chromosome 6: Score - 399.0   Time: 588.0 * Chromosome 7: Score - 394.8   Time: 570.8 * Chromosome 8: Score - 378.0   Time: 588.8 * Chromosome 9: Score - 365.4   Time: 564.2 * Chromosome 10: Score - 344.4   Time: 542.0 *
# Best Chromosome for Run 16 -> Longest Alive: 2637.2    High Score: 562.8
# Chromosome 1: Score - 516.6   Time: 656.4 * Chromosome 2: Score - 457.8   Time: 662.0 * Chromosome 3: Score - 457.8   Time: 656.8 * Chromosome 4: Score - 445.2   Time: 605.6 * Chromosome 5: Score - 445.2   Time: 605.0 * Chromosome 6: Score - 441.0   Time: 624.2 * Chromosome 7: Score - 441.0   Time: 608.2 * Chromosome 8: Score - 424.2   Time: 621.6 * Chromosome 9: Score - 390.6   Time: 548.2 * Chromosome 10: Score - 378.0   Time: 538.2 *
# Best Chromosome for Run 17 -> Longest Alive: 656.4    High Score: 516.6
# Chromosome 1: Score - 449.4   Time: 621.8 * Chromosome 2: Score - 441.0   Time: 608.6 * Chromosome 3: Score - 436.8   Time: 622.2 * Chromosome 4: Score - 432.6   Time: 643.8 * Chromosome 5: Score - 420.0   Time: 624.6 * Chromosome 6: Score - 415.8   Time: 614.4 * Chromosome 7: Score - 399.0   Time: 558.0 * Chromosome 8: Score - 394.8   Time: 599.6 * Chromosome 9: Score - 390.6   Time: 599.0 * Chromosome 10: Score - 130.2   Time: 413.0 *
# Best Chromosome for Run 18 -> Longest Alive: 621.8    High Score: 449.4
# Chromosome 1: Score - 483.0   Time: 662.8 * Chromosome 2: Score - 483.0   Time: 614.8 * Chromosome 3: Score - 474.6   Time: 650.4 * Chromosome 4: Score - 432.6   Time: 659.2 * Chromosome 5: Score - 432.6   Time: 613.6 * Chromosome 6: Score - 428.4   Time: 607.2 * Chromosome 7: Score - 424.2   Time: 617.6 * Chromosome 8: Score - 403.2   Time: 541.0 * Chromosome 9: Score - 382.2   Time: 627.8 * Chromosome 10: Score - 352.8   Time: 556.4 *
# Best Chromosome for Run 19 -> Longest Alive: 662.8    High Score: 483.0
# Chromosome 1: Score - 495.6   Time: 661.8 * Chromosome 2: Score - 474.6   Time: 648.8 * Chromosome 3: Score - 457.8   Time: 660.0 * Chromosome 4: Score - 453.6   Time: 644.8 * Chromosome 5: Score - 441.0   Time: 612.2 * Chromosome 6: Score - 432.6   Time: 660.8 * Chromosome 7: Score - 428.4   Time: 712.8 * Chromosome 8: Score - 411.6   Time: 589.2 * Chromosome 9: Score - 344.4   Time: 544.2 * Chromosome 10: Score - 310.8   Time: 458.6 *
# Best Chromosome for Run 20 -> Longest Alive: 661.8    High Score: 495.6
# Chromosome 1: Score - 487.2   Time: 673.4 * Chromosome 2: Score - 470.4   Time: 670.2 * Chromosome 3: Score - 457.8   Time: 644.4 * Chromosome 4: Score - 441.0   Time: 596.2 * Chromosome 5: Score - 424.2   Time: 618.4 * Chromosome 6: Score - 407.4   Time: 538.0 * Chromosome 7: Score - 399.0   Time: 573.8 * Chromosome 8: Score - 390.6   Time: 638.2 * Chromosome 9: Score - 357.0   Time: 538.2 * Chromosome 10: Score - 336.0   Time: 1677.8 *
# Best Chromosome for Run 21 -> Longest Alive: 673.4    High Score: 487.2
# Chromosome 1: Score - 470.4   Time: 660.6 * Chromosome 2: Score - 445.2   Time: 618.2 * Chromosome 3: Score - 436.8   Time: 640.8 * Chromosome 4: Score - 432.6   Time: 617.8 * Chromosome 5: Score - 390.6   Time: 602.0 * Chromosome 6: Score - 386.4   Time: 611.4 * Chromosome 7: Score - 386.4   Time: 531.0 * Chromosome 8: Score - 382.2   Time: 555.8 * Chromosome 9: Score - 373.8   Time: 626.8 * Chromosome 10: Score - 357.0   Time: 506.8 *
# Best Chromosome for Run 22 -> Longest Alive: 660.6    High Score: 470.4
# Chromosome 1: Score - 470.4   Time: 668.4 * Chromosome 2: Score - 453.6   Time: 641.6 * Chromosome 3: Score - 436.8   Time: 615.0 * Chromosome 4: Score - 420.0   Time: 596.6 * Chromosome 5: Score - 407.4   Time: 545.4 * Chromosome 6: Score - 394.8   Time: 544.2 * Chromosome 7: Score - 378.0   Time: 598.8 * Chromosome 8: Score - 378.0   Time: 582.2 * Chromosome 9: Score - 357.0   Time: 532.2 * Chromosome 10: Score - 336.0   Time: 518.4 *
# Best Chromosome for Run 23 -> Longest Alive: 668.4    High Score: 470.4
# Chromosome 1: Score - 453.6   Time: 637.4 * Chromosome 2: Score - 453.6   Time: 622.2 * Chromosome 3: Score - 445.2   Time: 614.4 * Chromosome 4: Score - 428.4   Time: 619.0 * Chromosome 5: Score - 424.2   Time: 627.6 * Chromosome 6: Score - 420.0   Time: 611.4 * Chromosome 7: Score - 382.2   Time: 585.2 * Chromosome 8: Score - 369.6   Time: 551.6 * Chromosome 9: Score - 365.4   Time: 614.6 * Chromosome 10: Score - 344.4   Time: 553.0 *
# Best Chromosome for Run 24 -> Longest Alive: 637.4    High Score: 453.6
# Chromosome 1: Score - 453.6   Time: 647.0 * Chromosome 2: Score - 445.2   Time: 655.8 * Chromosome 3: Score - 441.0   Time: 651.0 * Chromosome 4: Score - 441.0   Time: 609.2 * Chromosome 5: Score - 436.8   Time: 621.4 * Chromosome 6: Score - 390.6   Time: 624.4 * Chromosome 7: Score - 369.6   Time: 570.6 * Chromosome 8: Score - 357.0   Time: 502.0 * Chromosome 9: Score - 336.0   Time: 566.4 * Chromosome 10: Score - 331.8   Time: 512.0 *
# Best Chromosome for Run 25 -> Longest Alive: 647.0    High Score: 453.6
# Chromosome 1: Score - 470.4   Time: 625.2 * Chromosome 2: Score - 466.2   Time: 627.6 * Chromosome 3: Score - 441.0   Time: 636.8 * Chromosome 4: Score - 436.8   Time: 630.8 * Chromosome 5: Score - 428.4   Time: 667.2 * Chromosome 6: Score - 424.2   Time: 630.8 * Chromosome 7: Score - 411.6   Time: 604.8 * Chromosome 8: Score - 394.8   Time: 626.6 * Chromosome 9: Score - 394.8   Time: 562.6 * Chromosome 10: Score - 327.6   Time: 509.2 *
# Best Chromosome for Run 26 -> Longest Alive: 625.2    High Score: 470.4
# Chromosome 1: Score - 474.6   Time: 700.2 * Chromosome 2: Score - 470.4   Time: 668.8 * Chromosome 3: Score - 453.6   Time: 637.4 * Chromosome 4: Score - 424.2   Time: 609.2 * Chromosome 5: Score - 420.0   Time: 663.6 * Chromosome 6: Score - 415.8   Time: 610.6 * Chromosome 7: Score - 415.8   Time: 577.2 * Chromosome 8: Score - 411.6   Time: 598.8 * Chromosome 9: Score - 399.0   Time: 550.8 * Chromosome 10: Score - 361.2   Time: 609.0 *
# Best Chromosome for Run 27 -> Longest Alive: 700.2    High Score: 474.6
# Chromosome 1: Score - 441.0   Time: 610.6 * Chromosome 2: Score - 432.6   Time: 639.0 * Chromosome 3: Score - 420.0   Time: 615.6 * Chromosome 4: Score - 420.0   Time: 596.4 * Chromosome 5: Score - 403.2   Time: 627.2 * Chromosome 6: Score - 399.0   Time: 623.6 * Chromosome 7: Score - 394.8   Time: 613.6 * Chromosome 8: Score - 378.0   Time: 596.6 * Chromosome 9: Score - 373.8   Time: 519.4 * Chromosome 10: Score - 315.0   Time: 534.8 *
# Best Chromosome for Run 28 -> Longest Alive: 610.6    High Score: 441.0
# Chromosome 1: Score - 483.0   Time: 625.2 * Chromosome 2: Score - 466.2   Time: 679.4 * Chromosome 3: Score - 466.2   Time: 667.0 * Chromosome 4: Score - 466.2   Time: 650.0 * Chromosome 5: Score - 445.2   Time: 644.8 * Chromosome 6: Score - 445.2   Time: 641.6 * Chromosome 7: Score - 428.4   Time: 667.0 * Chromosome 8: Score - 420.0   Time: 605.6 * Chromosome 9: Score - 394.8   Time: 574.2 * Chromosome 10: Score - 352.8   Time: 579.8 *
# Best Chromosome for Run 29 -> Longest Alive: 625.2    High Score: 483.0
# Chromosome 1: Score - 478.8   Time: 663.4 * Chromosome 2: Score - 449.4   Time: 642.8 * Chromosome 3: Score - 432.6   Time: 647.4 * Chromosome 4: Score - 415.8   Time: 621.8 * Chromosome 5: Score - 399.0   Time: 641.6 * Chromosome 6: Score - 394.8   Time: 598.6 * Chromosome 7: Score - 386.4   Time: 545.4 * Chromosome 8: Score - 382.2   Time: 566.2 * Chromosome 9: Score - 315.0   Time: 534.0 * Chromosome 10: Score - 315.0   Time: 521.8 *
# Best Chromosome for Run 30 -> Longest Alive: 663.4    High Score: 478.8
# Chromosome 1: Score - 478.8   Time: 633.4 * Chromosome 2: Score - 462.0   Time: 634.8 * Chromosome 3: Score - 432.6   Time: 686.2 * Chromosome 4: Score - 424.2   Time: 609.4 * Chromosome 5: Score - 424.2   Time: 608.2 * Chromosome 6: Score - 369.6   Time: 565.8 * Chromosome 7: Score - 365.4   Time: 545.2 * Chromosome 8: Score - 361.2   Time: 542.0 * Chromosome 9: Score - 344.4   Time: 538.0 * Chromosome 10: Score - 268.8   Time: 572.6 *
# Best Chromosome for Run 31 -> Longest Alive: 633.4    High Score: 478.8
# Chromosome 1: Score - 546.0   Time: 722.4 * Chromosome 2: Score - 453.6   Time: 619.0 * Chromosome 3: Score - 449.4   Time: 670.2 * Chromosome 4: Score - 445.2   Time: 654.4 * Chromosome 5: Score - 441.0   Time: 636.6 * Chromosome 6: Score - 386.4   Time: 564.4 * Chromosome 7: Score - 382.2   Time: 570.6 * Chromosome 8: Score - 378.0   Time: 591.8 * Chromosome 9: Score - 373.8   Time: 630.6 * Chromosome 10: Score - 348.6   Time: 601.8 *
# Best Chromosome for Run 32 -> Longest Alive: 722.4    High Score: 546.0
# Chromosome 1: Score - 466.2   Time: 659.6 * Chromosome 2: Score - 445.2   Time: 604.6 * Chromosome 3: Score - 399.0   Time: 619.0 * Chromosome 4: Score - 394.8   Time: 596.6 * Chromosome 5: Score - 390.6   Time: 609.2 * Chromosome 6: Score - 386.4   Time: 601.2 * Chromosome 7: Score - 386.4   Time: 590.0 * Chromosome 8: Score - 373.8   Time: 593.4 * Chromosome 9: Score - 357.0   Time: 520.2 * Chromosome 10: Score - 340.2   Time: 509.6 *
# Best Chromosome for Run 33 -> Longest Alive: 659.6    High Score: 466.2
# Chromosome 1: Score - 487.2   Time: 657.0 * Chromosome 2: Score - 436.8   Time: 675.4 * Chromosome 3: Score - 432.6   Time: 573.0 * Chromosome 4: Score - 394.8   Time: 597.0 * Chromosome 5: Score - 373.8   Time: 595.2 * Chromosome 6: Score - 373.8   Time: 555.4 * Chromosome 7: Score - 365.4   Time: 621.8 * Chromosome 8: Score - 361.2   Time: 580.6 * Chromosome 9: Score - 348.6   Time: 564.6 * Chromosome 10: Score - 336.0   Time: 593.4 *
# Best Chromosome for Run 34 -> Longest Alive: 657.0    High Score: 487.2
# Chromosome 1: Score - 453.6   Time: 639.2 * Chromosome 2: Score - 453.6   Time: 620.8 * Chromosome 3: Score - 441.0   Time: 663.4 * Chromosome 4: Score - 436.8   Time: 653.4 * Chromosome 5: Score - 420.0   Time: 644.8 * Chromosome 6: Score - 411.6   Time: 636.6 * Chromosome 7: Score - 399.0   Time: 625.4 * Chromosome 8: Score - 390.6   Time: 570.2 * Chromosome 9: Score - 348.6   Time: 516.8 * Chromosome 10: Score - 336.0   Time: 483.2 *
# Best Chromosome for Run 35 -> Longest Alive: 639.2    High Score: 453.6
# Chromosome 1: Score - 504.0   Time: 667.0 * Chromosome 2: Score - 483.0   Time: 691.0 * Chromosome 3: Score - 457.8   Time: 641.6 * Chromosome 4: Score - 428.4   Time: 625.4 * Chromosome 5: Score - 394.8   Time: 569.8 * Chromosome 6: Score - 390.6   Time: 563.2 * Chromosome 7: Score - 382.2   Time: 582.6 * Chromosome 8: Score - 365.4   Time: 563.6 * Chromosome 9: Score - 348.6   Time: 503.2 * Chromosome 10: Score - 302.4   Time: 532.8 *
# Best Chromosome for Run 36 -> Longest Alive: 667.0    High Score: 504.0
# Chromosome 1: Score - 470.4   Time: 644.8 * Chromosome 2: Score - 441.0   Time: 643.0 * Chromosome 3: Score - 411.6   Time: 631.4 * Chromosome 4: Score - 403.2   Time: 657.4 * Chromosome 5: Score - 399.0   Time: 582.2 * Chromosome 6: Score - 378.0   Time: 611.4 * Chromosome 7: Score - 336.0   Time: 541.8 * Chromosome 8: Score - 319.2   Time: 510.6 * Chromosome 9: Score - 294.0   Time: 519.4 * Chromosome 10: Score - 285.6   Time: 466.2 *
# Best Chromosome for Run 37 -> Longest Alive: 644.8    High Score: 470.4
# Chromosome 1: Score - 462.0   Time: 634.8 * Chromosome 2: Score - 457.8   Time: 635.0 * Chromosome 3: Score - 453.6   Time: 660.8 * Chromosome 4: Score - 453.6   Time: 630.8 * Chromosome 5: Score - 411.6   Time: 596.0 * Chromosome 6: Score - 403.2   Time: 604.0 * Chromosome 7: Score - 382.2   Time: 607.0 * Chromosome 8: Score - 373.8   Time: 566.6 * Chromosome 9: Score - 348.6   Time: 585.6 * Chromosome 10: Score - 340.2   Time: 576.6 *
# Best Chromosome for Run 38 -> Longest Alive: 634.8    High Score: 462.0
# Chromosome 1: Score - 483.0   Time: 657.2 * Chromosome 2: Score - 453.6   Time: 640.2 * Chromosome 3: Score - 436.8   Time: 604.4 * Chromosome 4: Score - 394.8   Time: 619.2 * Chromosome 5: Score - 382.2   Time: 534.4 * Chromosome 6: Score - 378.0   Time: 579.6 * Chromosome 7: Score - 369.6   Time: 569.8 * Chromosome 8: Score - 369.6   Time: 492.6 * Chromosome 9: Score - 348.6   Time: 541.6 * Chromosome 10: Score - 315.0   Time: 513.4 *
# Best Chromosome for Run 39 -> Longest Alive: 657.2    High Score: 483.0
# Chromosome 1: Score - 495.6   Time: 644.4 * Chromosome 2: Score - 428.4   Time: 646.6 * Chromosome 3: Score - 390.6   Time: 564.2 * Chromosome 4: Score - 378.0   Time: 618.6 * Chromosome 5: Score - 369.6   Time: 534.4 * Chromosome 6: Score - 365.4   Time: 608.4 * Chromosome 7: Score - 357.0   Time: 486.4 * Chromosome 8: Score - 352.8   Time: 541.0 * Chromosome 9: Score - 319.2   Time: 486.4 * Chromosome 10: Score - 268.8   Time: 438.8 *
# Best Chromosome for Run 40 -> Longest Alive: 644.4    High Score: 495.6
# Chromosome 1: Score - 470.4   Time: 657.0 * Chromosome 2: Score - 457.8   Time: 670.4 * Chromosome 3: Score - 457.8   Time: 653.0 * Chromosome 4: Score - 436.8   Time: 644.8 * Chromosome 5: Score - 394.8   Time: 630.0 * Chromosome 6: Score - 394.8   Time: 587.0 * Chromosome 7: Score - 348.6   Time: 529.2 * Chromosome 8: Score - 336.0   Time: 495.2 * Chromosome 9: Score - 310.8   Time: 489.8 * Chromosome 10: Score - 294.0   Time: 516.4 *
# Best Chromosome for Run 41 -> Longest Alive: 657.0    High Score: 470.4
# Chromosome 1: Score - 462.0   Time: 694.0 * Chromosome 2: Score - 457.8   Time: 631.0 * Chromosome 3: Score - 441.0   Time: 671.6 * Chromosome 4: Score - 420.0   Time: 642.6 * Chromosome 5: Score - 415.8   Time: 603.0 * Chromosome 6: Score - 394.8   Time: 612.4 * Chromosome 7: Score - 386.4   Time: 595.6 * Chromosome 8: Score - 369.6   Time: 541.4 * Chromosome 9: Score - 352.8   Time: 576.2 * Chromosome 10: Score - 294.0   Time: 519.8 *
# Best Chromosome for Run 42 -> Longest Alive: 694.0    High Score: 462.0
# Chromosome 1: Score - 474.6   Time: 650.8 * Chromosome 2: Score - 432.6   Time: 580.2 * Chromosome 3: Score - 428.4   Time: 640.4 * Chromosome 4: Score - 428.4   Time: 612.6 * Chromosome 5: Score - 415.8   Time: 638.0 * Chromosome 6: Score - 411.6   Time: 608.2 * Chromosome 7: Score - 411.6   Time: 579.6 * Chromosome 8: Score - 390.6   Time: 592.2 * Chromosome 9: Score - 386.4   Time: 550.8 * Chromosome 10: Score - 382.2   Time: 534.6 *
# Best Chromosome for Run 43 -> Longest Alive: 650.8    High Score: 474.6
# Chromosome 1: Score - 462.0   Time: 666.0 * Chromosome 2: Score - 449.4   Time: 660.8 * Chromosome 3: Score - 436.8   Time: 638.2 * Chromosome 4: Score - 436.8   Time: 608.0 * Chromosome 5: Score - 420.0   Time: 597.8 * Chromosome 6: Score - 420.0   Time: 577.2 * Chromosome 7: Score - 394.8   Time: 644.8 * Chromosome 8: Score - 386.4   Time: 598.4 * Chromosome 9: Score - 382.2   Time: 608.8 * Chromosome 10: Score - 382.2   Time: 576.0 *
# Best Chromosome for Run 44 -> Longest Alive: 666.0    High Score: 462.0
# Chromosome 1: Score - 508.2   Time: 660.6 * Chromosome 2: Score - 487.2   Time: 682.6 * Chromosome 3: Score - 462.0   Time: 663.6 * Chromosome 4: Score - 441.0   Time: 621.6 * Chromosome 5: Score - 436.8   Time: 599.6 * Chromosome 6: Score - 428.4   Time: 634.2 * Chromosome 7: Score - 403.2   Time: 615.6 * Chromosome 8: Score - 386.4   Time: 561.4 * Chromosome 9: Score - 378.0   Time: 599.4 * Chromosome 10: Score - 348.6   Time: 583.0 *
# Best Chromosome for Run 45 -> Longest Alive: 660.6    High Score: 508.2
# Chromosome 1: Score - 483.0   Time: 687.8 * Chromosome 2: Score - 483.0   Time: 659.0 * Chromosome 3: Score - 478.8   Time: 673.4 * Chromosome 4: Score - 474.6   Time: 664.8 * Chromosome 5: Score - 428.4   Time: 658.0 * Chromosome 6: Score - 403.2   Time: 636.8 * Chromosome 7: Score - 390.6   Time: 598.4 * Chromosome 8: Score - 378.0   Time: 576.4 * Chromosome 9: Score - 378.0   Time: 568.0 * Chromosome 10: Score - 352.8   Time: 514.4 *
# Best Chromosome for Run 46 -> Longest Alive: 687.8    High Score: 483.0
# Chromosome 1: Score - 470.4   Time: 672.0 * Chromosome 2: Score - 466.2   Time: 663.8 * Chromosome 3: Score - 462.0   Time: 638.0 * Chromosome 4: Score - 457.8   Time: 637.0 * Chromosome 5: Score - 453.6   Time: 625.8 * Chromosome 6: Score - 445.2   Time: 637.2 * Chromosome 7: Score - 424.2   Time: 631.4 * Chromosome 8: Score - 407.4   Time: 619.0 * Chromosome 9: Score - 394.8   Time: 577.0 * Chromosome 10: Score - 357.0   Time: 567.4 *
# Best Chromosome for Run 47 -> Longest Alive: 672.0    High Score: 470.4
# Chromosome 1: Score - 520.8   Time: 676.4 * Chromosome 2: Score - 457.8   Time: 675.2 * Chromosome 3: Score - 449.4   Time: 670.4 * Chromosome 4: Score - 432.6   Time: 643.0 * Chromosome 5: Score - 415.8   Time: 583.4 * Chromosome 6: Score - 411.6   Time: 598.0 * Chromosome 7: Score - 399.0   Time: 563.8 * Chromosome 8: Score - 394.8   Time: 595.8 * Chromosome 9: Score - 382.2   Time: 634.8 * Chromosome 10: Score - 369.6   Time: 607.6 *
# Best Chromosome for Run 48 -> Longest Alive: 676.4    High Score: 520.8
# Chromosome 1: Score - 487.2   Time: 668.6 * Chromosome 2: Score - 470.4   Time: 634.6 * Chromosome 3: Score - 462.0   Time: 676.6 * Chromosome 4: Score - 449.4   Time: 634.4 * Chromosome 5: Score - 436.8   Time: 622.2 * Chromosome 6: Score - 420.0   Time: 582.6 * Chromosome 7: Score - 378.0   Time: 583.4 * Chromosome 8: Score - 373.8   Time: 590.0 * Chromosome 9: Score - 344.4   Time: 575.0 * Chromosome 10: Score - 315.0   Time: 543.0 *
# Best Chromosome for Run 49 -> Longest Alive: 668.6    High Score: 487.2
# Chromosome 1: Score - 470.4   Time: 589.0 * Chromosome 2: Score - 445.2   Time: 648.6 * Chromosome 3: Score - 445.2   Time: 637.6 * Chromosome 4: Score - 432.6   Time: 631.6 * Chromosome 5: Score - 415.8   Time: 615.8 * Chromosome 6: Score - 411.6   Time: 628.6 * Chromosome 7: Score - 394.8   Time: 589.4 * Chromosome 8: Score - 378.0   Time: 535.6 * Chromosome 9: Score - 365.4   Time: 599.8 * Chromosome 10: Score - 340.2   Time: 576.2 *
# Best Chromosome for Run 50 -> Longest Alive: 589.0    High Score: 470.4
# Chromosome 1: Score - 487.2   Time: 660.0 * Chromosome 2: Score - 474.6   Time: 638.2 * Chromosome 3: Score - 470.4   Time: 630.0 * Chromosome 4: Score - 445.2   Time: 592.2 * Chromosome 5: Score - 428.4   Time: 596.4 * Chromosome 6: Score - 411.6   Time: 563.4 * Chromosome 7: Score - 407.4   Time: 586.8 * Chromosome 8: Score - 386.4   Time: 592.2 * Chromosome 9: Score - 382.2   Time: 607.4 * Chromosome 10: Score - 352.8   Time: 529.4 *
# Best Chromosome for Run 51 -> Longest Alive: 660.0    High Score: 487.2
# Chromosome 1: Score - 483.0   Time: 649.6 * Chromosome 2: Score - 474.6   Time: 643.6 * Chromosome 3: Score - 462.0   Time: 650.8 * Chromosome 4: Score - 432.6   Time: 593.2 * Chromosome 5: Score - 415.8   Time: 586.6 * Chromosome 6: Score - 390.6   Time: 580.4 * Chromosome 7: Score - 382.2   Time: 580.4 * Chromosome 8: Score - 348.6   Time: 538.2 * Chromosome 9: Score - 340.2   Time: 550.4 * Chromosome 10: Score - 336.0   Time: 519.2 *
# Best Chromosome for Run 52 -> Longest Alive: 649.6    High Score: 483.0
# Chromosome 1: Score - 470.4   Time: 666.0 * Chromosome 2: Score - 428.4   Time: 650.2 * Chromosome 3: Score - 403.2   Time: 538.6 * Chromosome 4: Score - 394.8   Time: 641.6 * Chromosome 5: Score - 390.6   Time: 605.2 * Chromosome 6: Score - 378.0   Time: 551.4 * Chromosome 7: Score - 373.8   Time: 566.8 * Chromosome 8: Score - 361.2   Time: 588.4 * Chromosome 9: Score - 357.0   Time: 565.6 * Chromosome 10: Score - 331.8   Time: 544.2 *
# Best Chromosome for Run 53 -> Longest Alive: 666.0    High Score: 470.4
# Chromosome 1: Score - 483.0   Time: 681.4 * Chromosome 2: Score - 462.0   Time: 638.4 * Chromosome 3: Score - 457.8   Time: 654.4 * Chromosome 4: Score - 449.4   Time: 619.0 * Chromosome 5: Score - 441.0   Time: 651.2 * Chromosome 6: Score - 399.0   Time: 566.6 * Chromosome 7: Score - 382.2   Time: 605.0 * Chromosome 8: Score - 365.4   Time: 628.4 * Chromosome 9: Score - 361.2   Time: 532.4 * Chromosome 10: Score - 331.8   Time: 518.8 *
# Best Chromosome for Run 54 -> Longest Alive: 681.4    High Score: 483.0
# Chromosome 1: Score - 533.4   Time: 698.6 * Chromosome 2: Score - 453.6   Time: 633.4 * Chromosome 3: Score - 436.8   Time: 640.4 * Chromosome 4: Score - 415.8   Time: 626.8 * Chromosome 5: Score - 411.6   Time: 628.0 * Chromosome 6: Score - 382.2   Time: 614.6 * Chromosome 7: Score - 365.4   Time: 552.6 * Chromosome 8: Score - 352.8   Time: 511.8 * Chromosome 9: Score - 323.4   Time: 522.6 * Chromosome 10: Score - 323.4   Time: 494.0 *
# Best Chromosome for Run 55 -> Longest Alive: 698.6    High Score: 533.4
# Chromosome 1: Score - 474.6   Time: 630.2 * Chromosome 2: Score - 424.2   Time: 621.2 * Chromosome 3: Score - 415.8   Time: 560.8 * Chromosome 4: Score - 411.6   Time: 554.4 * Chromosome 5: Score - 394.8   Time: 570.2 * Chromosome 6: Score - 382.2   Time: 566.8 * Chromosome 7: Score - 365.4   Time: 602.8 * Chromosome 8: Score - 361.2   Time: 589.4 * Chromosome 9: Score - 361.2   Time: 538.2 * Chromosome 10: Score - 357.0   Time: 538.8 *
# Best Chromosome for Run 56 -> Longest Alive: 630.2    High Score: 474.6
# Chromosome 1: Score - 483.0   Time: 654.2 * Chromosome 2: Score - 453.6   Time: 628.8 * Chromosome 3: Score - 449.4   Time: 612.4 * Chromosome 4: Score - 436.8   Time: 630.6 * Chromosome 5: Score - 411.6   Time: 602.8 * Chromosome 6: Score - 407.4   Time: 609.2 * Chromosome 7: Score - 403.2   Time: 615.6 * Chromosome 8: Score - 340.2   Time: 554.2 * Chromosome 9: Score - 323.4   Time: 484.2 * Chromosome 10: Score - 235.2   Time: 492.6 *
# Best Chromosome for Run 57 -> Longest Alive: 654.2    High Score: 483.0
# Chromosome 1: Score - 499.8   Time: 669.6 * Chromosome 2: Score - 466.2   Time: 676.8 * Chromosome 3: Score - 457.8   Time: 651.0 * Chromosome 4: Score - 436.8   Time: 625.4 * Chromosome 5: Score - 411.6   Time: 634.2 * Chromosome 6: Score - 403.2   Time: 545.2 * Chromosome 7: Score - 399.0   Time: 606.0 * Chromosome 8: Score - 394.8   Time: 558.0 * Chromosome 9: Score - 357.0   Time: 558.2 * Chromosome 10: Score - 315.0   Time: 583.6 *
# Best Chromosome for Run 58 -> Longest Alive: 669.6    High Score: 499.8
# Chromosome 1: Score - 478.8   Time: 672.0 * Chromosome 2: Score - 462.0   Time: 656.4 * Chromosome 3: Score - 457.8   Time: 669.2 * Chromosome 4: Score - 457.8   Time: 614.8 * Chromosome 5: Score - 449.4   Time: 647.8 * Chromosome 6: Score - 436.8   Time: 615.0 * Chromosome 7: Score - 432.6   Time: 599.4 * Chromosome 8: Score - 428.4   Time: 622.0 * Chromosome 9: Score - 403.2   Time: 605.2 * Chromosome 10: Score - 403.2   Time: 591.2 *
# Best Chromosome for Run 59 -> Longest Alive: 672.0    High Score: 478.8
# Chromosome 1: Score - 470.4   Time: 638.0 * Chromosome 2: Score - 449.4   Time: 640.2 * Chromosome 3: Score - 449.4   Time: 615.8 * Chromosome 4: Score - 407.4   Time: 641.4 * Chromosome 5: Score - 394.8   Time: 564.4 * Chromosome 6: Score - 394.8   Time: 563.2 * Chromosome 7: Score - 386.4   Time: 592.4 * Chromosome 8: Score - 373.8   Time: 602.4 * Chromosome 9: Score - 369.6   Time: 537.6 * Chromosome 10: Score - 361.2   Time: 557.4 *
# Best Chromosome for Run 60 -> Longest Alive: 638.0    High Score: 470.4
# Chromosome 1: Score - 478.8   Time: 688.4 * Chromosome 2: Score - 453.6   Time: 634.0 * Chromosome 3: Score - 428.4   Time: 611.2 * Chromosome 4: Score - 424.2   Time: 641.4 * Chromosome 5: Score - 420.0   Time: 592.2 * Chromosome 6: Score - 415.8   Time: 692.2 * Chromosome 7: Score - 411.6   Time: 643.4 * Chromosome 8: Score - 394.8   Time: 639.8 * Chromosome 9: Score - 369.6   Time: 541.8 * Chromosome 10: Score - 348.6   Time: 555.0 *
# Best Chromosome for Run 61 -> Longest Alive: 688.4    High Score: 478.8
# Chromosome 1: Score - 533.4   Time: 670.2 * Chromosome 2: Score - 449.4   Time: 606.2 * Chromosome 3: Score - 441.0   Time: 629.4 * Chromosome 4: Score - 428.4   Time: 644.4 * Chromosome 5: Score - 428.4   Time: 621.8 * Chromosome 6: Score - 394.8   Time: 602.8 * Chromosome 7: Score - 390.6   Time: 554.0 * Chromosome 8: Score - 373.8   Time: 601.0 * Chromosome 9: Score - 361.2   Time: 521.8 * Chromosome 10: Score - 357.0   Time: 602.4 *
# Best Chromosome for Run 62 -> Longest Alive: 670.2    High Score: 533.4
# Chromosome 1: Score - 462.0   Time: 634.6 * Chromosome 2: Score - 445.2   Time: 656.4 * Chromosome 3: Score - 436.8   Time: 644.4 * Chromosome 4: Score - 432.6   Time: 630.4 * Chromosome 5: Score - 420.0   Time: 608.4 * Chromosome 6: Score - 403.2   Time: 586.0 * Chromosome 7: Score - 399.0   Time: 562.2 * Chromosome 8: Score - 378.0   Time: 571.6 * Chromosome 9: Score - 373.8   Time: 606.4 * Chromosome 10: Score - 348.6   Time: 589.6 *
# Best Chromosome for Run 63 -> Longest Alive: 634.6    High Score: 462.0
# Chromosome 1: Score - 487.2   Time: 663.6 * Chromosome 2: Score - 470.4   Time: 670.6 * Chromosome 3: Score - 441.0   Time: 631.2 * Chromosome 4: Score - 441.0   Time: 627.6 * Chromosome 5: Score - 424.2   Time: 662.0 * Chromosome 6: Score - 394.8   Time: 602.6 * Chromosome 7: Score - 382.2   Time: 590.0 * Chromosome 8: Score - 357.0   Time: 541.2 * Chromosome 9: Score - 352.8   Time: 514.0 * Chromosome 10: Score - 336.0   Time: 523.6 *
# Best Chromosome for Run 64 -> Longest Alive: 663.6    High Score: 487.2
# Chromosome 1: Score - 445.2   Time: 596.4 * Chromosome 2: Score - 436.8   Time: 562.4 * Chromosome 3: Score - 399.0   Time: 579.6 * Chromosome 4: Score - 399.0   Time: 560.6 * Chromosome 5: Score - 394.8   Time: 621.8 * Chromosome 6: Score - 361.2   Time: 580.4 * Chromosome 7: Score - 340.2   Time: 531.2 * Chromosome 8: Score - 306.6   Time: 544.2 * Chromosome 9: Score - 285.6   Time: 583.6 * Chromosome 10: Score - 285.6   Time: 513.4 *
# Best Chromosome for Run 65 -> Longest Alive: 596.4    High Score: 445.2
# Chromosome 1: Score - 495.6   Time: 638.4 * Chromosome 2: Score - 441.0   Time: 612.0 * Chromosome 3: Score - 436.8   Time: 653.0 * Chromosome 4: Score - 432.6   Time: 656.2 * Chromosome 5: Score - 428.4   Time: 585.8 * Chromosome 6: Score - 424.2   Time: 596.2 * Chromosome 7: Score - 369.6   Time: 576.4 * Chromosome 8: Score - 361.2   Time: 563.4 * Chromosome 9: Score - 352.8   Time: 567.4 * Chromosome 10: Score - 336.0   Time: 509.4 *
# Best Chromosome for Run 66 -> Longest Alive: 638.4    High Score: 495.6
# Chromosome 1: Score - 495.6   Time: 670.2 * Chromosome 2: Score - 495.6   Time: 669.0 * Chromosome 3: Score - 466.2   Time: 658.8 * Chromosome 4: Score - 428.4   Time: 598.4 * Chromosome 5: Score - 411.6   Time: 595.8 * Chromosome 6: Score - 411.6   Time: 583.8 * Chromosome 7: Score - 403.2   Time: 618.8 * Chromosome 8: Score - 373.8   Time: 587.0 * Chromosome 9: Score - 373.8   Time: 571.2 * Chromosome 10: Score - 361.2   Time: 532.2 *
# Best Chromosome for Run 67 -> Longest Alive: 670.2    High Score: 495.6
# Chromosome 1: Score - 474.6   Time: 662.0 * Chromosome 2: Score - 474.6   Time: 644.0 * Chromosome 3: Score - 466.2   Time: 630.6 * Chromosome 4: Score - 441.0   Time: 596.8 * Chromosome 5: Score - 407.4   Time: 587.2 * Chromosome 6: Score - 403.2   Time: 622.2 * Chromosome 7: Score - 390.6   Time: 619.2 * Chromosome 8: Score - 382.2   Time: 562.2 * Chromosome 9: Score - 352.8   Time: 586.4 * Chromosome 10: Score - 352.8   Time: 579.6 *
# Best Chromosome for Run 68 -> Longest Alive: 662.0    High Score: 474.6
# Chromosome 1: Score - 457.8   Time: 638.2 * Chromosome 2: Score - 441.0   Time: 652.4 * Chromosome 3: Score - 432.6   Time: 660.4 * Chromosome 4: Score - 428.4   Time: 607.6 * Chromosome 5: Score - 399.0   Time: 599.4 * Chromosome 6: Score - 378.0   Time: 591.6 * Chromosome 7: Score - 378.0   Time: 558.8 * Chromosome 8: Score - 373.8   Time: 555.2 * Chromosome 9: Score - 361.2   Time: 535.4 * Chromosome 10: Score - 315.0   Time: 499.4 *
# Best Chromosome for Run 69 -> Longest Alive: 638.2    High Score: 457.8
# Chromosome 1: Score - 504.0   Time: 681.4 * Chromosome 2: Score - 457.8   Time: 636.2 * Chromosome 3: Score - 403.2   Time: 615.8 * Chromosome 4: Score - 403.2   Time: 598.6 * Chromosome 5: Score - 390.6   Time: 597.6 * Chromosome 6: Score - 386.4   Time: 564.6 * Chromosome 7: Score - 382.2   Time: 591.8 * Chromosome 8: Score - 373.8   Time: 576.2 * Chromosome 9: Score - 373.8   Time: 512.8 * Chromosome 10: Score - 340.2   Time: 580.4 *
# Best Chromosome for Run 70 -> Longest Alive: 681.4    High Score: 504.0
# Chromosome 1: Score - 466.2   Time: 631.8 * Chromosome 2: Score - 462.0   Time: 660.0 * Chromosome 3: Score - 462.0   Time: 643.6 * Chromosome 4: Score - 462.0   Time: 632.0 * Chromosome 5: Score - 453.6   Time: 633.4 * Chromosome 6: Score - 436.8   Time: 569.0 * Chromosome 7: Score - 420.0   Time: 577.2 * Chromosome 8: Score - 394.8   Time: 657.2 * Chromosome 9: Score - 336.0   Time: 548.2 * Chromosome 10: Score - 336.0   Time: 532.4 *
# Best Chromosome for Run 71 -> Longest Alive: 631.8    High Score: 466.2
# Chromosome 1: Score - 487.2   Time: 705.4 * Chromosome 2: Score - 424.2   Time: 599.6 * Chromosome 3: Score - 394.8   Time: 612.6 * Chromosome 4: Score - 394.8   Time: 603.0 * Chromosome 5: Score - 390.6   Time: 554.8 * Chromosome 6: Score - 382.2   Time: 589.4 * Chromosome 7: Score - 373.8   Time: 651.0 * Chromosome 8: Score - 352.8   Time: 599.0 * Chromosome 9: Score - 352.8   Time: 497.4 * Chromosome 10: Score - 336.0   Time: 586.4 *
# Best Chromosome for Run 72 -> Longest Alive: 705.4    High Score: 487.2
# Chromosome 1: Score - 487.2   Time: 638.0 * Chromosome 2: Score - 474.6   Time: 672.6 * Chromosome 3: Score - 462.0   Time: 641.4 * Chromosome 4: Score - 445.2   Time: 573.2 * Chromosome 5: Score - 424.2   Time: 611.0 * Chromosome 6: Score - 411.6   Time: 598.0 * Chromosome 7: Score - 399.0   Time: 591.8 * Chromosome 8: Score - 365.4   Time: 583.6 * Chromosome 9: Score - 365.4   Time: 566.6 * Chromosome 10: Score - 357.0   Time: 532.4 *
# Best Chromosome for Run 73 -> Longest Alive: 638.0    High Score: 487.2
# Chromosome 1: Score - 504.0   Time: 704.8 * Chromosome 2: Score - 457.8   Time: 614.6 * Chromosome 3: Score - 407.4   Time: 608.0 * Chromosome 4: Score - 407.4   Time: 549.8 * Chromosome 5: Score - 403.2   Time: 657.4 * Chromosome 6: Score - 390.6   Time: 576.8 * Chromosome 7: Score - 369.6   Time: 593.4 * Chromosome 8: Score - 348.6   Time: 526.0 * Chromosome 9: Score - 336.0   Time: 534.8 * Chromosome 10: Score - 336.0   Time: 494.0 *
# Best Chromosome for Run 74 -> Longest Alive: 704.8    High Score: 504.0
# Chromosome 1: Score - 533.4   Time: 673.6 * Chromosome 2: Score - 462.0   Time: 601.8 * Chromosome 3: Score - 457.8   Time: 640.8 * Chromosome 4: Score - 449.4   Time: 577.2 * Chromosome 5: Score - 445.2   Time: 649.2 * Chromosome 6: Score - 420.0   Time: 586.0 * Chromosome 7: Score - 415.8   Time: 669.4 * Chromosome 8: Score - 407.4   Time: 558.6 * Chromosome 9: Score - 361.2   Time: 530.8 * Chromosome 10: Score - 357.0   Time: 574.2 *
# Best Chromosome for Run 75 -> Longest Alive: 673.6    High Score: 533.4
# Chromosome 1: Score - 466.2   Time: 640.4 * Chromosome 2: Score - 445.2   Time: 622.2 * Chromosome 3: Score - 424.2   Time: 612.2 * Chromosome 4: Score - 420.0   Time: 579.4 * Chromosome 5: Score - 415.8   Time: 595.0 * Chromosome 6: Score - 415.8   Time: 576.4 * Chromosome 7: Score - 399.0   Time: 573.6 * Chromosome 8: Score - 386.4   Time: 634.4 * Chromosome 9: Score - 382.2   Time: 544.0 * Chromosome 10: Score - 373.8   Time: 619.0 *
# Best Chromosome for Run 76 -> Longest Alive: 640.4    High Score: 466.2
# Chromosome 1: Score - 449.4   Time: 643.8 * Chromosome 2: Score - 432.6   Time: 618.6 * Chromosome 3: Score - 428.4   Time: 599.4 * Chromosome 4: Score - 411.6   Time: 540.8 * Chromosome 5: Score - 399.0   Time: 602.0 * Chromosome 6: Score - 394.8   Time: 555.0 * Chromosome 7: Score - 386.4   Time: 628.2 * Chromosome 8: Score - 361.2   Time: 586.8 * Chromosome 9: Score - 361.2   Time: 576.8 * Chromosome 10: Score - 348.6   Time: 545.0 *
# Best Chromosome for Run 77 -> Longest Alive: 643.8    High Score: 449.4
# Chromosome 1: Score - 512.4   Time: 614.6 * Chromosome 2: Score - 495.6   Time: 651.0 * Chromosome 3: Score - 491.4   Time: 666.8 * Chromosome 4: Score - 462.0   Time: 659.6 * Chromosome 5: Score - 445.2   Time: 630.8 * Chromosome 6: Score - 436.8   Time: 633.6 * Chromosome 7: Score - 411.6   Time: 575.6 * Chromosome 8: Score - 390.6   Time: 557.8 * Chromosome 9: Score - 331.8   Time: 512.2 * Chromosome 10: Score - 315.0   Time: 535.0 *
# Best Chromosome for Run 78 -> Longest Alive: 614.6    High Score: 512.4
# Chromosome 1: Score - 491.4   Time: 690.6 * Chromosome 2: Score - 462.0   Time: 654.2 * Chromosome 3: Score - 449.4   Time: 684.4 * Chromosome 4: Score - 415.8   Time: 602.6 * Chromosome 5: Score - 411.6   Time: 563.2 * Chromosome 6: Score - 407.4   Time: 596.8 * Chromosome 7: Score - 403.2   Time: 605.6 * Chromosome 8: Score - 399.0   Time: 612.2 * Chromosome 9: Score - 382.2   Time: 612.2 * Chromosome 10: Score - 365.4   Time: 559.2 *
# Best Chromosome for Run 79 -> Longest Alive: 690.6    High Score: 491.4
# Chromosome 1: Score - 508.2   Time: 679.6 * Chromosome 2: Score - 491.4   Time: 637.2 * Chromosome 3: Score - 449.4   Time: 586.8 * Chromosome 4: Score - 436.8   Time: 588.2 * Chromosome 5: Score - 424.2   Time: 582.6 * Chromosome 6: Score - 420.0   Time: 594.8 * Chromosome 7: Score - 390.6   Time: 583.0 * Chromosome 8: Score - 386.4   Time: 567.6 * Chromosome 9: Score - 373.8   Time: 584.6 * Chromosome 10: Score - 369.6   Time: 579.6 *
# Best Chromosome for Run 80 -> Longest Alive: 679.6    High Score: 508.2
# Chromosome 1: Score - 462.0   Time: 657.2 * Chromosome 2: Score - 449.4   Time: 665.6 * Chromosome 3: Score - 445.2   Time: 579.2 * Chromosome 4: Score - 432.6   Time: 631.6 * Chromosome 5: Score - 432.6   Time: 612.2 * Chromosome 6: Score - 407.4   Time: 612.4 * Chromosome 7: Score - 403.2   Time: 593.2 * Chromosome 8: Score - 399.0   Time: 592.2 * Chromosome 9: Score - 382.2   Time: 597.8 * Chromosome 10: Score - 382.2   Time: 551.4 *
# Best Chromosome for Run 81 -> Longest Alive: 657.2    High Score: 462.0
# Chromosome 1: Score - 474.6   Time: 659.8 * Chromosome 2: Score - 470.4   Time: 633.2 * Chromosome 3: Score - 462.0   Time: 673.4 * Chromosome 4: Score - 457.8   Time: 639.8 * Chromosome 5: Score - 449.4   Time: 606.0 * Chromosome 6: Score - 424.2   Time: 651.0 * Chromosome 7: Score - 407.4   Time: 612.8 * Chromosome 8: Score - 407.4   Time: 609.0 * Chromosome 9: Score - 382.2   Time: 603.2 * Chromosome 10: Score - 378.0   Time: 545.2 *
# Best Chromosome for Run 82 -> Longest Alive: 659.8    High Score: 474.6
# Chromosome 1: Score - 487.2   Time: 695.6 * Chromosome 2: Score - 441.0   Time: 615.6 * Chromosome 3: Score - 424.2   Time: 641.2 * Chromosome 4: Score - 424.2   Time: 607.8 * Chromosome 5: Score - 420.0   Time: 605.2 * Chromosome 6: Score - 411.6   Time: 634.4 * Chromosome 7: Score - 407.4   Time: 606.0 * Chromosome 8: Score - 403.2   Time: 618.2 * Chromosome 9: Score - 399.0   Time: 595.6 * Chromosome 10: Score - 331.8   Time: 553.6 *
# Best Chromosome for Run 83 -> Longest Alive: 695.6    High Score: 487.2
# Chromosome 1: Score - 487.2   Time: 677.8 * Chromosome 2: Score - 470.4   Time: 656.8 * Chromosome 3: Score - 436.8   Time: 607.0 * Chromosome 4: Score - 420.0   Time: 643.4 * Chromosome 5: Score - 411.6   Time: 618.8 * Chromosome 6: Score - 390.6   Time: 578.4 * Chromosome 7: Score - 390.6   Time: 541.4 * Chromosome 8: Score - 369.6   Time: 556.8 * Chromosome 9: Score - 357.0   Time: 554.6 * Chromosome 10: Score - 331.8   Time: 531.0 *
# Best Chromosome for Run 84 -> Longest Alive: 677.8    High Score: 487.2
# Chromosome 1: Score - 466.2   Time: 669.0 * Chromosome 2: Score - 449.4   Time: 639.0 * Chromosome 3: Score - 428.4   Time: 659.8 * Chromosome 4: Score - 420.0   Time: 586.8 * Chromosome 5: Score - 420.0   Time: 579.6 * Chromosome 6: Score - 415.8   Time: 649.6 * Chromosome 7: Score - 411.6   Time: 537.0 * Chromosome 8: Score - 365.4   Time: 512.0 * Chromosome 9: Score - 352.8   Time: 624.4 * Chromosome 10: Score - 331.8   Time: 532.6 *
# Best Chromosome for Run 85 -> Longest Alive: 669.0    High Score: 466.2
# Chromosome 1: Score - 508.2   Time: 686.2 * Chromosome 2: Score - 483.0   Time: 685.8 * Chromosome 3: Score - 462.0   Time: 652.6 * Chromosome 4: Score - 445.2   Time: 606.2 * Chromosome 5: Score - 424.2   Time: 606.0 * Chromosome 6: Score - 407.4   Time: 638.2 * Chromosome 7: Score - 407.4   Time: 560.8 * Chromosome 8: Score - 399.0   Time: 593.4 * Chromosome 9: Score - 378.0   Time: 606.0 * Chromosome 10: Score - 369.6   Time: 558.0 *
# Best Chromosome for Run 86 -> Longest Alive: 686.2    High Score: 508.2
# Chromosome 1: Score - 487.2   Time: 660.4 * Chromosome 2: Score - 483.0   Time: 655.8 * Chromosome 3: Score - 462.0   Time: 647.8 * Chromosome 4: Score - 445.2   Time: 624.4 * Chromosome 5: Score - 432.6   Time: 631.8 * Chromosome 6: Score - 432.6   Time: 623.0 * Chromosome 7: Score - 415.8   Time: 630.8 * Chromosome 8: Score - 411.6   Time: 670.2 * Chromosome 9: Score - 382.2   Time: 611.6 * Chromosome 10: Score - 323.4   Time: 563.2 *
# Best Chromosome for Run 87 -> Longest Alive: 660.4    High Score: 487.2
# Chromosome 1: Score - 462.0   Time: 681.0 * Chromosome 2: Score - 457.8   Time: 622.0 * Chromosome 3: Score - 449.4   Time: 632.0 * Chromosome 4: Score - 441.0   Time: 669.4 * Chromosome 5: Score - 436.8   Time: 660.6 * Chromosome 6: Score - 420.0   Time: 640.4 * Chromosome 7: Score - 411.6   Time: 602.8 * Chromosome 8: Score - 386.4   Time: 590.2 * Chromosome 9: Score - 378.0   Time: 547.4 * Chromosome 10: Score - 315.0   Time: 529.0 *
# Best Chromosome for Run 88 -> Longest Alive: 681.0    High Score: 462.0
# Chromosome 1: Score - 462.0   Time: 637.2 * Chromosome 2: Score - 436.8   Time: 598.0 * Chromosome 3: Score - 428.4   Time: 617.8 * Chromosome 4: Score - 415.8   Time: 615.8 * Chromosome 5: Score - 411.6   Time: 588.4 * Chromosome 6: Score - 399.0   Time: 582.4 * Chromosome 7: Score - 390.6   Time: 567.8 * Chromosome 8: Score - 373.8   Time: 600.0 * Chromosome 9: Score - 365.4   Time: 604.2 * Chromosome 10: Score - 319.2   Time: 561.0 *
# Best Chromosome for Run 89 -> Longest Alive: 637.2    High Score: 462.0
# Chromosome 1: Score - 470.4   Time: 711.2 * Chromosome 2: Score - 470.4   Time: 666.8 * Chromosome 3: Score - 466.2   Time: 593.4 * Chromosome 4: Score - 436.8   Time: 648.0 * Chromosome 5: Score - 424.2   Time: 651.0 * Chromosome 6: Score - 420.0   Time: 615.2 * Chromosome 7: Score - 411.6   Time: 604.2 * Chromosome 8: Score - 399.0   Time: 616.8 * Chromosome 9: Score - 382.2   Time: 608.4 * Chromosome 10: Score - 361.2   Time: 568.6 *
# Best Chromosome for Run 90 -> Longest Alive: 711.2    High Score: 470.4
# Chromosome 1: Score - 516.6   Time: 673.0 * Chromosome 2: Score - 483.0   Time: 659.8 * Chromosome 3: Score - 462.0   Time: 655.4 * Chromosome 4: Score - 457.8   Time: 631.8 * Chromosome 5: Score - 441.0   Time: 665.8 * Chromosome 6: Score - 424.2   Time: 583.2 * Chromosome 7: Score - 415.8   Time: 596.6 * Chromosome 8: Score - 415.8   Time: 569.4 * Chromosome 9: Score - 394.8   Time: 584.0 * Chromosome 10: Score - 323.4   Time: 561.0 *
# Best Chromosome for Run 91 -> Longest Alive: 673.0    High Score: 516.6
# Chromosome 1: Score - 529.2   Time: 709.2 * Chromosome 2: Score - 466.2   Time: 622.2 * Chromosome 3: Score - 462.0   Time: 668.8 * Chromosome 4: Score - 441.0   Time: 641.0 * Chromosome 5: Score - 424.2   Time: 667.0 * Chromosome 6: Score - 420.0   Time: 636.2 * Chromosome 7: Score - 407.4   Time: 611.6 * Chromosome 8: Score - 373.8   Time: 619.0 * Chromosome 9: Score - 365.4   Time: 519.2 * Chromosome 10: Score - 348.6   Time: 564.6 *
# Best Chromosome for Run 92 -> Longest Alive: 709.2    High Score: 529.2
# Chromosome 1: Score - 495.6   Time: 647.0 * Chromosome 2: Score - 441.0   Time: 622.2 * Chromosome 3: Score - 428.4   Time: 631.4 * Chromosome 4: Score - 420.0   Time: 622.4 * Chromosome 5: Score - 403.2   Time: 547.2 * Chromosome 6: Score - 390.6   Time: 622.2 * Chromosome 7: Score - 390.6   Time: 607.4 * Chromosome 8: Score - 390.6   Time: 583.0 * Chromosome 9: Score - 390.6   Time: 573.0 * Chromosome 10: Score - 386.4   Time: 538.8 *
# Best Chromosome for Run 93 -> Longest Alive: 647.0    High Score: 495.6
# Chromosome 1: Score - 483.0   Time: 637.8 * Chromosome 2: Score - 483.0   Time: 622.0 * Chromosome 3: Score - 474.6   Time: 686.2 * Chromosome 4: Score - 457.8   Time: 647.0 * Chromosome 5: Score - 441.0   Time: 606.2 * Chromosome 6: Score - 436.8   Time: 641.4 * Chromosome 7: Score - 424.2   Time: 625.6 * Chromosome 8: Score - 403.2   Time: 622.0 * Chromosome 9: Score - 382.2   Time: 635.2 * Chromosome 10: Score - 336.0   Time: 602.8 *
# Best Chromosome for Run 94 -> Longest Alive: 637.8    High Score: 483.0
# Chromosome 1: Score - 487.2   Time: 606.0 * Chromosome 2: Score - 466.2   Time: 660.8 * Chromosome 3: Score - 462.0   Time: 659.0 * Chromosome 4: Score - 449.4   Time: 666.6 * Chromosome 5: Score - 432.6   Time: 605.8 * Chromosome 6: Score - 428.4   Time: 656.6 * Chromosome 7: Score - 415.8   Time: 592.2 * Chromosome 8: Score - 407.4   Time: 614.4 * Chromosome 9: Score - 399.0   Time: 617.2 * Chromosome 10: Score - 394.8   Time: 619.2 *
# Best Chromosome for Run 95 -> Longest Alive: 606.0    High Score: 487.2
# Chromosome 1: Score - 533.4   Time: 650.8 * Chromosome 2: Score - 462.0   Time: 657.4 * Chromosome 3: Score - 436.8   Time: 571.0 * Chromosome 4: Score - 428.4   Time: 620.2 * Chromosome 5: Score - 415.8   Time: 623.0 * Chromosome 6: Score - 407.4   Time: 599.6 * Chromosome 7: Score - 382.2   Time: 594.4 * Chromosome 8: Score - 378.0   Time: 593.2 * Chromosome 9: Score - 340.2   Time: 592.4 * Chromosome 10: Score - 319.2   Time: 467.6 *
# Best Chromosome for Run 96 -> Longest Alive: 650.8    High Score: 533.4
# Chromosome 1: Score - 491.4   Time: 656.6 * Chromosome 2: Score - 457.8   Time: 646.8 * Chromosome 3: Score - 445.2   Time: 641.6 * Chromosome 4: Score - 432.6   Time: 660.4 * Chromosome 5: Score - 424.2   Time: 603.0 * Chromosome 6: Score - 411.6   Time: 570.0 * Chromosome 7: Score - 407.4   Time: 596.0 * Chromosome 8: Score - 394.8   Time: 554.4 * Chromosome 9: Score - 365.4   Time: 567.4 * Chromosome 10: Score - 315.0   Time: 500.6 *
# Best Chromosome for Run 97 -> Longest Alive: 656.6    High Score: 491.4
# Chromosome 1: Score - 474.6   Time: 669.4 * Chromosome 2: Score - 445.2   Time: 660.0 * Chromosome 3: Score - 441.0   Time: 627.0 * Chromosome 4: Score - 428.4   Time: 644.6 * Chromosome 5: Score - 407.4   Time: 589.0 * Chromosome 6: Score - 407.4   Time: 554.4 * Chromosome 7: Score - 386.4   Time: 554.2 * Chromosome 8: Score - 361.2   Time: 561.4 * Chromosome 9: Score - 340.2   Time: 554.8 * Chromosome 10: Score - 336.0   Time: 534.8 *
# Best Chromosome for Run 98 -> Longest Alive: 669.4    High Score: 474.6
# Chromosome 1: Score - 483.0   Time: 642.6 * Chromosome 2: Score - 428.4   Time: 623.2 * Chromosome 3: Score - 424.2   Time: 594.6 * Chromosome 4: Score - 411.6   Time: 636.2 * Chromosome 5: Score - 411.6   Time: 628.6 * Chromosome 6: Score - 390.6   Time: 571.2 * Chromosome 7: Score - 352.8   Time: 544.4 * Chromosome 8: Score - 340.2   Time: 496.0 * Chromosome 9: Score - 336.0   Time: 526.0 * Chromosome 10: Score - 327.6   Time: 567.6 *
# Best Chromosome for Run 99 -> Longest Alive: 642.6    High Score: 483.0
# Chromosome 1: Score - 491.4   Time: 663.6 * Chromosome 2: Score - 445.2   Time: 592.0 * Chromosome 3: Score - 436.8   Time: 633.8 * Chromosome 4: Score - 420.0   Time: 611.8 * Chromosome 5: Score - 411.6   Time: 623.4 * Chromosome 6: Score - 407.4   Time: 609.6 * Chromosome 7: Score - 403.2   Time: 600.0 * Chromosome 8: Score - 378.0   Time: 606.0 * Chromosome 9: Score - 344.4   Time: 501.6 * Chromosome 10: Score - 319.2   Time: 555.0 *
# Best Chromosome for Run 100 -> Longest Alive: 663.6    High Score: 491.4
# Best Chromosome -> Longest Alive: 1694.6    High Score: 684.6

# %%
"""
This displays the game to evaluate our best chromosome.
"""
test_env = gym.make('ALE/Assault-v5', render_mode="human", full_action_space=False)

file = open("mlp_s684.pickle",'rb')
best_chromo = pickle.load(file)

done = False
obs = test_env.reset()

time_alive = 0
reward_sum = 0

while(done == False):

    action = best_chromo.nn(obs_to_tensor(obs))
    
    obs, reward, done, info = test_env.step(action)

    reward_sum = reward_sum + reward
    time_alive = time_alive + 1

print(f"Longest Alive: {time_alive}    High Score: {reward_sum}")

file.close()
# Out:
# c:\Users\icarus\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\container.py:204: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Longest Alive: 1735    High Score: 630.0
